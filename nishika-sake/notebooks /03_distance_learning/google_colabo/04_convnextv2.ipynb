# %% [markdown]
# <a href="https://colab.research.google.com/github/ryota0051/nishika-sake/blob/main/nishika-sake/notebooks%20/03_distance_learning/google_colabo/04_convnextv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Sep  9 12:53:38 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install faiss-gpu
# !pip install japanize_matplotlib
# !pip install 'git+https://github.com/katsura-jp/pytorch-cosine-annealing-with-warmup'
# !pip install timm
# !pip install transformers
# !pip install albumentations
# !pip install pytorch-metric-learning
# !pip install https://storage.googleapis.com/tpu-pytorch/wheels/colab/torch_xla-2.0-cp310-cp310-linux_x86_64.whl
# Out:
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 20.1 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2
# Collecting japanize_matplotlib
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 19.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from japanize_matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.16.0)
# Building wheels for collected packages: japanize_matplotlib
#   Building wheel for japanize_matplotlib (setup.py) ... done
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=edd6d140b4faacba7bcad23610d7d119e12a04294ccd6a157de36a4d6b82021a
#   Stored in directory: /root/.cache/pip/wheels/61/7a/6b/df1f79be9c59862525070e157e62b08eab8ece27c1b68fbb94
# Successfully built japanize_matplotlib
# Installing collected packages: japanize_matplotlib
# Successfully installed japanize_matplotlib-1.1.3
# Collecting git+https://github.com/katsura-jp/pytorch-cosine-annealing-with-warmup
#   Cloning https://github.com/katsura-jp/pytorch-cosine-annealing-with-warmup to /tmp/pip-req-build-7wxtndvd
#   Running command git clone --filter=blob:none --quiet https://github.com/katsura-jp/pytorch-cosine-annealing-with-warmup /tmp/pip-req-build-7wxtndvd
#   Resolved https://github.com/katsura-jp/pytorch-cosine-annealing-with-warmup to commit 12d03c07553aedd3d9e9155e2b3e31ce8c64081a
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: cosine-annealing-warmup
#   Building wheel for cosine-annealing-warmup (setup.py) ... done
#   Created wheel for cosine-annealing-warmup: filename=cosine_annealing_warmup-2.0-py3-none-any.whl size=4166 sha256=50ae3e7dff2639a3cdb07536ff24d8ed0eb1f4214bae5e03af312dbe2d0e176d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xlk8tds7/wheels/29/26/10/bf1a07417dd54aa73bdf09ce4f31c187974a444a1cedddbd99
# Successfully built cosine-annealing-warmup
# Installing collected packages: cosine-annealing-warmup
# Successfully installed cosine-annealing-warmup-2.0
# Collecting timm
#   Downloading timm-0.9.7-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.15.2+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Collecting huggingface-hub (from timm)
#   Downloading huggingface_hub-0.17.1-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 19.0 MB/s eta 0:00:00
# Collecting safetensors (from timm)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: safetensors, huggingface-hub, timm
# Successfully installed huggingface-hub-0.17.1 safetensors-0.3.3 timm-0.9.7
# Collecting transformers
#   Downloading transformers-4.33.1-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 53.2 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.13.3 transformers-4.33.1
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (1.3.1)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.11.2)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.19.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (4.8.0.76)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (1.2.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (4.5.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2.31.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2023.8.30)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (23.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.2.0)
# Collecting pytorch-metric-learning
#   Downloading pytorch_metric_learning-2.3.0-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->pytorch-metric-learning) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->pytorch-metric-learning) (16.0.6)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->pytorch-metric-learning) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->pytorch-metric-learning) (1.3.0)
# Installing collected packages: pytorch-metric-learning
# Successfully installed pytorch-metric-learning-2.3.0

# %%
# !git clone https://github.com/ryota0051/nishika-sake.git
# Out:
# Cloning into 'nishika-sake'...
# remote: Enumerating objects: 257, done.
# remote: Total 257 (delta 0), reused 0 (delta 0), pack-reused 257
# Receiving objects: 100% (257/257), 84.97 MiB | 17.93 MiB/s, done.
# Resolving deltas: 100% (97/97), done.

# %%
# !ls /content/drive/MyDrive/competition/nishika_sake
# Out:
# inputs	intermidiates  notebooks  outputs  submissions

# %%
# !ls
# Out:
# drive  nishika-sake  sample_data

# %% [markdown]
# ## 概要
#
# - convnextv2(gloval_average_pooling => gemに変更) + arcface を用いて meigara の予測 タスクを実行
# - 学習済みモデルを用いて test, cite の画像の embedding を取得し、それらの距離から類似画像を選択
# - 回転

# %% [markdown]
# ## Library

# %%
import datetime
import gc
import itertools
import json
import logging
import os
import shutil
import math
from pathlib import Path
import sys

import albumentations as A
import cv2
import japanize_matplotlib
import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import timm
import torch
import torch.nn as nn
import torch.nn.functional as F

from albumentations import ImageOnlyTransform
from albumentations.pytorch import ToTensorV2
from cosine_annealing_warmup import CosineAnnealingWarmupRestarts
from PIL import Image
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from torch.cuda.amp import GradScaler, autocast
from torch.optim import Adam, AdamW
from torch.optim.lr_scheduler import (
    CosineAnnealingLR,
    CosineAnnealingWarmRestarts,
    MultiStepLR,
    ReduceLROnPlateau,
)
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
from transformers import get_cosine_schedule_with_warmup, get_linear_schedule_with_warmup
from torch.utils.tensorboard import SummaryWriter
import faiss
from pytorch_metric_learning import losses

sys.path.append('./nishika-sake')
from src.searcher import SimilaritySearcher
from src.const import OUTPUT_ROOT, DATA_ROOT, QUERY_IMAGES_PATH, CITE_IMAGES_PATH
from src.layer import GeM
from src.layer.elastic_face import ElasticCosFace
from src.layer.arcface import ArcMarginProduct
from src.utils import seed_torch, mrr_at_k_by_searched_index

# %%
timm.list_models('*convnext*', pretrained=True)
# Out:
# ['convnext_atto.d2_in1k',
#  'convnext_atto_ols.a2_in1k',
#  'convnext_base.clip_laion2b',
#  'convnext_base.clip_laion2b_augreg',
#  'convnext_base.clip_laion2b_augreg_ft_in1k',
#  'convnext_base.clip_laion2b_augreg_ft_in12k',
#  'convnext_base.clip_laion2b_augreg_ft_in12k_in1k',
#  'convnext_base.clip_laion2b_augreg_ft_in12k_in1k_384',
#  'convnext_base.clip_laiona',
#  'convnext_base.clip_laiona_320',
#  'convnext_base.clip_laiona_augreg_320',
#  'convnext_base.clip_laiona_augreg_ft_in1k_384',
#  'convnext_base.fb_in1k',
#  'convnext_base.fb_in22k',
#  'convnext_base.fb_in22k_ft_in1k',
#  'convnext_base.fb_in22k_ft_in1k_384',
#  'convnext_femto.d1_in1k',
#  'convnext_femto_ols.d1_in1k',
#  'convnext_large.fb_in1k',
#  'convnext_large.fb_in22k',
#  'convnext_large.fb_in22k_ft_in1k',
#  'convnext_large.fb_in22k_ft_in1k_384',
#  'convnext_large_mlp.clip_laion2b_augreg',
#  'convnext_large_mlp.clip_laion2b_augreg_ft_in1k',
#  'convnext_large_mlp.clip_laion2b_augreg_ft_in1k_384',
#  'convnext_large_mlp.clip_laion2b_augreg_ft_in12k_384',
#  'convnext_large_mlp.clip_laion2b_ft_320',
#  'convnext_large_mlp.clip_laion2b_ft_soup_320',
#  'convnext_large_mlp.clip_laion2b_soup_ft_in12k_320',
#  'convnext_large_mlp.clip_laion2b_soup_ft_in12k_384',
#  'convnext_large_mlp.clip_laion2b_soup_ft_in12k_in1k_320',
#  'convnext_large_mlp.clip_laion2b_soup_ft_in12k_in1k_384',
#  'convnext_nano.d1h_in1k',
#  'convnext_nano.in12k',
#  'convnext_nano.in12k_ft_in1k',
#  'convnext_nano_ols.d1h_in1k',
#  'convnext_pico.d1_in1k',
#  'convnext_pico_ols.d1_in1k',
#  'convnext_small.fb_in1k',
#  'convnext_small.fb_in22k',
#  'convnext_small.fb_in22k_ft_in1k',
#  'convnext_small.fb_in22k_ft_in1k_384',
#  'convnext_small.in12k',
#  'convnext_small.in12k_ft_in1k',
#  'convnext_small.in12k_ft_in1k_384',
#  'convnext_tiny.fb_in1k',
#  'convnext_tiny.fb_in22k',
#  'convnext_tiny.fb_in22k_ft_in1k',
#  'convnext_tiny.fb_in22k_ft_in1k_384',
#  'convnext_tiny.in12k',
#  'convnext_tiny.in12k_ft_in1k',
#  'convnext_tiny.in12k_ft_in1k_384',
#  'convnext_tiny_hnf.a2h_in1k',
#  'convnext_xlarge.fb_in22k',
#  'convnext_xlarge.fb_in22k_ft_in1k',
#  'convnext_xlarge.fb_in22k_ft_in1k_384',
#  'convnext_xxlarge.clip_laion2b_rewind',
#  'convnext_xxlarge.clip_laion2b_soup',
#  'convnext_xxlarge.clip_laion2b_soup_ft_in1k',
#  'convnextv2_atto.fcmae',
#  'convnextv2_atto.fcmae_ft_in1k',
#  'convnextv2_base.fcmae',
#  'convnextv2_base.fcmae_ft_in1k',
#  'convnextv2_base.fcmae_ft_in22k_in1k',
#  'convnextv2_base.fcmae_ft_in22k_in1k_384',
#  'convnextv2_femto.fcmae',
#  'convnextv2_femto.fcmae_ft_in1k',
#  'convnextv2_huge.fcmae',
#  'convnextv2_huge.fcmae_ft_in1k',
#  'convnextv2_huge.fcmae_ft_in22k_in1k_384',
#  'convnextv2_huge.fcmae_ft_in22k_in1k_512',
#  'convnextv2_large.fcmae',
#  'convnextv2_large.fcmae_ft_in1k',
#  'convnextv2_large.fcmae_ft_in22k_in1k',
#  'convnextv2_large.fcmae_ft_in22k_in1k_384',
#  'convnextv2_nano.fcmae',
#  'convnextv2_nano.fcmae_ft_in1k',
#  'convnextv2_nano.fcmae_ft_in22k_in1k',
#  'convnextv2_nano.fcmae_ft_in22k_in1k_384',
#  'convnextv2_pico.fcmae',
#  'convnextv2_pico.fcmae_ft_in1k',
#  'convnextv2_tiny.fcmae',
#  'convnextv2_tiny.fcmae_ft_in1k',
#  'convnextv2_tiny.fcmae_ft_in22k_in1k',
#  'convnextv2_tiny.fcmae_ft_in22k_in1k_384']

# %% [markdown]
# ## Config

# %%
class Config:
    competition = "sake"
    name = "convnextv2"

    debug = False
    use_amp = True

    training = True
    evaluation = True
    embedding = True
    embedding_dim = 512
    use_plus = True
    s = 30
    m = 0.35

    seed = 8823
    n_fold = 3
    trn_fold = [
        0,
        1,
        2,3,
        4
    ]

    target_columns = ["meigara_label"]
    size = 448

    model_name = "convnextv2_large.fcmae_ft_in22k_in1k_384"
    max_epochs = 5
    train_batch_size = 8
    valid_batch_size = 55
    num_workers = 4
    gradient_accumulation_steps = 1
    clip_grad_norm = 1000
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    optimizer = dict(
        optimizer_name="AdamW",
        lr=1e-4,
        weight_decay=1e-2,
        eps=1e-6,
        beta=(0.9, 0.999),
        encoder_lr=1e-4,
        decoder_lr=1e-4,
    )

    scheduler = dict(
        scheduler_name="cosine",
        num_warmup_steps_rate=0.1,
        num_cycles=0.5,
    )
    batch_scheduler = True


if Config.debug:
    Config.max_epochs = 2
    Config.n_fold = 2
    Config.trn_fold = [0, 1]
    Config.name = Config.name + "_debug"

# %% [markdown]
# ## Const

# %%
HOME = Path("/content/drive/MyDrive/competition/nishika_sake")
NOTEBOOK_NAME = requests.get("http://172.28.0.12:9000/api/sessions").json()[0]["name"][:-6]
EXP_NAME = Config.name if Config.name is not None else NOTEBOOK_NAME
INPUTS = HOME / "inputs"  # input data
OUTPUTS = HOME / "outputs"
INTERMIDIATES = HOME / "intermidiates"  # intermidiate outputs
SUBMISSIONS = HOME / "submissions"
OUTPUTS_EXP = OUTPUTS / EXP_NAME
EXP_MODELS = OUTPUTS_EXP / "models"
EXP_REPORTS = OUTPUTS_EXP / "reports"
EXP_PREDS = OUTPUTS_EXP / "predictions"
SCRIPTS = HOME / "scripts"

CITE_IMAGES = Path("cite_images")
QUERY_IMAGES = Path("query_images")

# %% [markdown]
# ## Setup

# %%
def setup(Config):

    for d in [
        HOME,
        INPUTS,
        SUBMISSIONS,
        EXP_MODELS,
        EXP_REPORTS,
        EXP_PREDS,
        INTERMIDIATES,
    ]:
        d.mkdir(parents=True, exist_ok=True)

def check_file_exists(folder_path, file_name):
    folder = Path(folder_path)
    for file_path in folder.glob("**/*"):
        if file_path.is_file() and file_path.stem == file_name:
            return True
    return False


def create_new_datasets_in_kaggle(dataset_name, upload_dir):
    from kaggle.api.kaggle_api_extended import KaggleApi

    dataset_metadata = {}
    dataset_metadata["id"] = f'{os.environ["KAGGLE_USERNAME"]}/{dataset_name}'
    dataset_metadata["licenses"] = [{"name": "CC0-1.0"}]
    dataset_metadata["title"] = dataset_name
    with open(os.path.join(upload_dir, "dataset-metadata.json"), "w") as f:
        json.dump(dataset_metadata, f, indent=4)
    api = KaggleApi()
    api.authenticate()
    api.dataset_create_new(folder=upload_dir, convert_to_csv=False, dir_mode="tar")


class Logger:
    def __init__(self, path):
        self.general_logger = logging.getLogger(path)
        stream_handler = logging.StreamHandler()
        file_general_handler = logging.FileHandler(os.path.join(path, "Experiment.log"))
        if len(self.general_logger.handlers) == 0:
            self.general_logger.addHandler(stream_handler)
            self.general_logger.addHandler(file_general_handler)
            self.general_logger.setLevel(logging.INFO)

    def info(self, message):
        # display time
        self.general_logger.info("[{}] - {}".format(self.now_string(), message))

    @staticmethod
    def now_string():
        return str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))


def copy_file(source_file, destination_file):
    try:
        shutil.copy(source_file, destination_file)
        print("copy complete")
    except IOError as e:
        print(f"copy error: {e}")

# %%
setup(Config)
LOGGER = Logger(OUTPUTS_EXP.as_posix())

# %%
# content 直下で解凍 (ターミナルで実行が良さそう)
if not QUERY_IMAGES.is_dir():
    query_images = (INPUTS / "query_images.zip").as_posix()
    ! cp $query_images .
    # ! cp /content/drive/MyDrive/competition/nishika_sake/inputs/query_images.zip .
    ! unzip ./query_images.zip

if not CITE_IMAGES.is_dir():
    cite_images = (INPUTS / "cite_images.zip").as_posix()
    ! cp $cite_images .
    # ! cp /content/drive/MyDrive/competition/nishika_sake/inputs/cite_images.zip .
    ! unzip ./cite_images.zip
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: cite_images/100029442.jpg
#   inflating: cite_images/100077258.jpg
#   inflating: cite_images/100019581.jpg
#   inflating: cite_images/100068378.jpg
#   inflating: cite_images/100036562.jpg
#   inflating: cite_images/100082979.jpg
#   inflating: cite_images/100070537.jpg
#   inflating: cite_images/100041932.jpg
#   inflating: cite_images/100039651.jpg
#   inflating: cite_images/100028984.jpg
#   inflating: cite_images/100007967.jpg
#   inflating: cite_images/100071629.jpg
#   inflating: cite_images/100046085.jpg
#   inflating: cite_images/100069066.jpg
#   inflating: cite_images/100066355.jpg
#   inflating: cite_images/100020300.jpg
#   inflating: cite_images/100105802.jpg
#   inflating: cite_images/100093874.jpg
#   inflating: cite_images/100056296.jpg
#   inflating: cite_images/100079275.jpg
#   inflating: cite_images/100030113.jpg
#   inflating: cite_images/100076146.jpg
#   inflating: cite_images/100039889.jpg
#   inflating: cite_images/100087801.jpg
#   inflating: cite_images/100062133.jpg
#   inflating: cite_images/100024166.jpg
#   inflating: cite_images/100023609.jpg
#   inflating: cite_images/100074989.jpg
#   inflating: cite_images/100034375.jpg
#   inflating: cite_images/100072320.jpg
#   inflating: cite_images/100098921.jpg
#   inflating: cite_images/100064542.jpg
#   inflating: cite_images/100022517.jpg
#   inflating: cite_images/100013912.jpg
#   inflating: cite_images/100055947.jpg
#   inflating: cite_images/100044692.jpg
#   inflating: cite_images/100032704.jpg
#   inflating: cite_images/100074751.jpg
#   inflating: cite_images/100065884.jpg
#   inflating: cite_images/100025278.jpg
#   inflating: cite_images/100054481.jpg
#   inflating: cite_images/100087815.jpg
#   inflating: cite_images/100024172.jpg
#   inflating: cite_images/100062127.jpg
#   inflating: cite_images/100065648.jpg
#   inflating: cite_images/100098935.jpg
#   inflating: cite_images/100072334.jpg
#   inflating: cite_images/100045598.jpg
#   inflating: cite_images/100034361.jpg
#   inflating: cite_images/100096918.jpg
#   inflating: cite_images/100022503.jpg
#   inflating: cite_images/100064556.jpg
#   inflating: cite_images/100044686.jpg
#   inflating: cite_images/100055953.jpg
#   inflating: cite_images/100013906.jpg
#   inflating: cite_images/100065890.jpg
#   inflating: cite_images/100074745.jpg
#   inflating: cite_images/100032710.jpg
#   inflating: cite_images/100063239.jpg
#   inflating: cite_images/100089838.jpg
#   inflating: cite_images/100054495.jpg
#   inflating: cite_images/100026765.jpg
#   inflating: cite_images/100009786.jpg
#   inflating: cite_images/100018853.jpg
#   inflating: cite_images/100060730.jpg
#   inflating: cite_images/100031219.jpg
#   inflating: cite_images/100029456.jpg
#   inflating: cite_images/100070523.jpg
#   inflating: cite_images/100036576.jpg
#   inflating: cite_images/100019595.jpg
#   inflating: cite_images/100007973.jpg
#   inflating: cite_images/100028990.jpg
#   inflating: cite_images/100039645.jpg
#   inflating: cite_images/100041926.jpg
#   inflating: cite_images/100069072.jpg
#   inflating: cite_images/100037668.jpg
#   inflating: cite_images/100046091.jpg
#   inflating: cite_images/100020314.jpg
#   inflating: cite_images/100066341.jpg
#   inflating: cite_images/100079261.jpg
#   inflating: cite_images/100008498.jpg
#   inflating: cite_images/100056282.jpg
#   inflating: cite_images/100093860.jpg
#   inflating: cite_images/100105816.jpg
#   inflating: cite_images/100028748.jpg
#   inflating: cite_images/100076152.jpg
#   inflating: cite_images/100030107.jpg
#   inflating: cite_images/100061348.jpg
#   inflating: cite_images/100079507.jpg
#   inflating: cite_images/100076634.jpg
#   inflating: cite_images/100048902.jpg
#   inflating: cite_images/100030661.jpg
#   inflating: cite_images/100041098.jpg
#   inflating: cite_images/100057822.jpg
#   inflating: cite_images/100069714.jpg
#   inflating: cite_images/100011877.jpg
#   inflating: cite_images/100094869.jpg
#   inflating: cite_images/100020472.jpg
#   inflating: cite_images/100066427.jpg
#   inflating: cite_images/100070245.jpg
#   inflating: cite_images/100036210.jpg
#   inflating: cite_images/100067739.jpg
#   inflating: cite_images/100039123.jpg
#   inflating: cite_images/100050195.jpg
#   inflating: cite_images/100026003.jpg
#   inflating: cite_images/100078619.jpg
#   inflating: cite_images/100060056.jpg
#   inflating: cite_images/100085964.jpg
#   inflating: cite_images/100040386.jpg
#   inflating: cite_images/100029330.jpg
#   inflating: cite_images/100074023.jpg
#   inflating: cite_images/100032076.jpg
#   inflating: cite_images/100091911.jpg
#   inflating: cite_images/100107967.jpg
#   inflating: cite_images/100022265.jpg
#   inflating: cite_images/100064230.jpg
#   inflating: cite_images/100035719.jpg
#   inflating: cite_images/100062899.jpg
#   inflating: cite_images/100088298.jpg
#   inflating: cite_images/100005802.jpg
#   inflating: cite_images/100052782.jpg
#   inflating: cite_images/100043857.jpg
#   inflating: cite_images/100072452.jpg
#   inflating: cite_images/100089186.jpg
#   inflating: cite_images/100034407.jpg
#   inflating: cite_images/100042591.jpg
#   inflating: cite_images/100033368.jpg
#   inflating: cite_images/100024614.jpg
#   inflating: cite_images/100099395.jpg
#   inflating: cite_images/100073994.jpg
#   inflating: cite_images/100062641.jpg
#   inflating: cite_images/100095587.jpg
#   inflating: cite_images/100030649.jpg
#   inflating: cite_images/100028006.jpg
#   inflating: cite_images/100027335.jpg
#   inflating: cite_images/100010599.jpg
#   inflating: cite_images/100061360.jpg
#   inflating: cite_images/100038215.jpg
#   inflating: cite_images/100094841.jpg
#   inflating: cite_images/100102837.jpg
#   inflating: cite_images/100085794.jpg
#   inflating: cite_images/100071173.jpg
#   inflating: cite_images/100037126.jpg
#   inflating: cite_images/100030891.jpg
#   inflating: cite_images/100021744.jpg
#   inflating: cite_images/100059827.jpg
#   inflating: cite_images/100067711.jpg
#   inflating: cite_images/100105180.jpg
#   inflating: cite_images/100068422.jpg
#   inflating: cite_images/100036238.jpg
#   inflating: cite_images/100001494.jpg
#   inflating: cite_images/100029318.jpg
#   inflating: cite_images/100077502.jpg
#   inflating: cite_images/100031557.jpg
#   inflating: cite_images/100094699.jpg
#   inflating: cite_images/100011687.jpg
#   inflating: cite_images/100000952.jpg
#   inflating: cite_images/100078631.jpg
#   inflating: cite_images/100046907.jpg
#   inflating: cite_images/100091939.jpg
#   inflating: cite_images/100025522.jpg
#   inflating: cite_images/100063577.jpg
#   inflating: cite_images/100052972.jpg
#   inflating: cite_images/100097390.jpg
#   inflating: cite_images/100014927.jpg
#   inflating: cite_images/100073764.jpg
#   inflating: cite_images/100035731.jpg
#   inflating: cite_images/100106489.jpg
#   inflating: cite_images/100064218.jpg
#   inflating: cite_images/100087183.jpg
#   inflating: cite_images/100107797.jpg
#   inflating: cite_images/100080834.jpg
#   inflating: cite_images/100003283.jpg
#   inflating: cite_images/100023153.jpg
#   inflating: cite_images/100065106.jpg
#   inflating: cite_images/100062669.jpg
#   inflating: cite_images/100013090.jpg
#   inflating: cite_images/100075315.jpg
#   inflating: cite_images/100033340.jpg
#   inflating: cite_images/100002823.jpg
#   inflating: cite_images/100081294.jpg
#   inflating: cite_images/100044876.jpg
#   inflating: cite_images/100075473.jpg
#   inflating: cite_images/100033426.jpg
#   inflating: cite_images/100034349.jpg
#   inflating: cite_images/100091087.jpg
#   inflating: cite_images/100023635.jpg
#   inflating: cite_images/100065660.jpg
#   inflating: cite_images/100014099.jpg
#   inflating: cite_images/100073002.jpg
#   inflating: cite_images/100090399.jpg
#   inflating: cite_images/100035057.jpg
#   inflating: cite_images/100015387.jpg
#   inflating: cite_images/100096930.jpg
#   inflating: cite_images/100100946.jpg
#   inflating: cite_images/100025244.jpg
#   inflating: cite_images/100089810.jpg
#   inflating: cite_images/100063211.jpg
#   inflating: cite_images/100032738.jpg
#   inflating: cite_images/100101480.jpg
#   inflating: cite_images/100005194.jpg
#   inflating: cite_images/100058287.jpg
#   inflating: cite_images/100077264.jpg
#   inflating: cite_images/100102189.jpg
#   inflating: cite_images/100031231.jpg
#   inflating: cite_images/100060718.jpg
#   inflating: cite_images/100037898.jpg
#   inflating: cite_images/100083483.jpg
#   inflating: cite_images/100078157.jpg
#   inflating: cite_images/100021022.jpg
#   inflating: cite_images/100048094.jpg
#   inflating: cite_images/100067077.jpg
#   inflating: cite_images/100068344.jpg
#   inflating: cite_images/100082945.jpg
#   inflating: cite_images/100093690.jpg
#   inflating: cite_images/100017590.jpg
#   inflating: cite_images/100066369.jpg
#   inflating: cite_images/100038573.jpg
#   inflating: cite_images/100071615.jpg
#   inflating: cite_images/100026995.jpg
#   inflating: cite_images/100009976.jpg
#   inflating: cite_images/100037640.jpg
#   inflating: cite_images/100103297.jpg
#   inflating: cite_images/100050803.jpg
#   inflating: cite_images/100007783.jpg
#   inflating: cite_images/100059199.jpg
#   inflating: cite_images/100028760.jpg
#   inflating: cite_images/100016856.jpg
#   inflating: cite_images/100093848.jpg
#   inflating: cite_images/100027453.jpg
#   inflating: cite_images/100079249.jpg
#   inflating: cite_images/100061406.jpg
#   inflating: cite_images/100031225.jpg
#   inflating: cite_images/100077270.jpg
#   inflating: cite_images/100006489.jpg
#   inflating: cite_images/100058293.jpg
#   inflating: cite_images/100026759.jpg
#   inflating: cite_images/100078143.jpg
#   inflating: cite_images/100083497.jpg
#   inflating: cite_images/100067063.jpg
#   inflating: cite_images/100039679.jpg
#   inflating: cite_images/100048080.jpg
#   inflating: cite_images/100021036.jpg
#   inflating: cite_images/100093684.jpg
#   inflating: cite_images/100082951.jpg
#   inflating: cite_images/100068350.jpg
#   inflating: cite_images/100020328.jpg
#   inflating: cite_images/100038567.jpg
#   inflating: cite_images/100017584.jpg
#   inflating: cite_images/100037654.jpg
#   inflating: cite_images/100009962.jpg
#   inflating: cite_images/100026981.jpg
#   inflating: cite_images/100071601.jpg
#   inflating: cite_images/100016842.jpg
#   inflating: cite_images/100028774.jpg
#   inflating: cite_images/100007797.jpg
#   inflating: cite_images/100050817.jpg
#   inflating: cite_images/100103283.jpg
#   inflating: cite_images/100061412.jpg
#   inflating: cite_images/100082789.jpg
#   inflating: cite_images/100027447.jpg
#   inflating: cite_images/100044862.jpg
#   inflating: cite_images/100081280.jpg
#   inflating: cite_images/100002837.jpg
#   inflating: cite_images/100033432.jpg
#   inflating: cite_images/100087829.jpg
#   inflating: cite_images/100075467.jpg
#   inflating: cite_images/100098909.jpg
#   inflating: cite_images/100072308.jpg
#   inflating: cite_images/100091093.jpg
#   inflating: cite_images/100065674.jpg
#   inflating: cite_images/100023621.jpg
#   inflating: cite_images/100035043.jpg
#   inflating: cite_images/100073016.jpg
#   inflating: cite_images/100100952.jpg
#   inflating: cite_images/100096924.jpg
#   inflating: cite_images/100015393.jpg
#   inflating: cite_images/100063205.jpg
#   inflating: cite_images/100089804.jpg
#   inflating: cite_images/100025250.jpg
#   inflating: cite_images/100005180.jpg
#   inflating: cite_images/100074779.jpg
#   inflating: cite_images/100101494.jpg
#   inflating: cite_images/100063563.jpg
#   inflating: cite_images/100025536.jpg
#   inflating: cite_images/100014933.jpg
#   inflating: cite_images/100097384.jpg
#   inflating: cite_images/100052966.jpg
#   inflating: cite_images/100035725.jpg
#   inflating: cite_images/100002189.jpg
#   inflating: cite_images/100073770.jpg
#   inflating: cite_images/100087197.jpg
#   inflating: cite_images/100022259.jpg
#   inflating: cite_images/100003297.jpg
#   inflating: cite_images/100080820.jpg
#   inflating: cite_images/100107783.jpg
#   inflating: cite_images/100065112.jpg
#   inflating: cite_images/100023147.jpg
#   inflating: cite_images/100086289.jpg
#   inflating: cite_images/100024628.jpg
#   inflating: cite_images/100013084.jpg
#   inflating: cite_images/100033354.jpg
#   inflating: cite_images/100075301.jpg
#   inflating: cite_images/100028012.jpg
#   inflating: cite_images/100076608.jpg
#   inflating: cite_images/100095593.jpg
#   inflating: cite_images/100021988.jpg
#   inflating: cite_images/100061374.jpg
#   inflating: cite_images/100027321.jpg
#   inflating: cite_images/100085780.jpg
#   inflating: cite_images/100102823.jpg
#   inflating: cite_images/100094855.jpg
#   inflating: cite_images/100038201.jpg
#   inflating: cite_images/100069728.jpg
#   inflating: cite_images/100037132.jpg
#   inflating: cite_images/100071167.jpg
#   inflating: cite_images/100067705.jpg
#   inflating: cite_images/100059833.jpg
#   inflating: cite_images/100021750.jpg
#   inflating: cite_images/100030885.jpg
#   inflating: cite_images/100070279.jpg
#   inflating: cite_images/100001480.jpg
#   inflating: cite_images/100068436.jpg
#   inflating: cite_images/100105194.jpg
#   inflating: cite_images/100031543.jpg
#   inflating: cite_images/100085958.jpg
#   inflating: cite_images/100077516.jpg
#   inflating: cite_images/100046913.jpg
#   inflating: cite_images/100078625.jpg
#   inflating: cite_images/100000946.jpg
#   inflating: cite_images/100011693.jpg
#   inflating: cite_images/100070292.jpg
#   inflating: cite_images/100093109.jpg
#   inflating: cite_images/100019224.jpg
#   inflating: cite_images/100016117.jpg
#   inflating: cite_images/100084475.jpg
#   inflating: cite_images/100050142.jpg
#   inflating: cite_images/100009037.jpg
#   inflating: cite_images/100060081.jpg
#   inflating: cite_images/100011678.jpg
#   inflating: cite_images/100040351.jpg
#   inflating: cite_images/100094666.jpg
#   inflating: cite_images/100102610.jpg
#   inflating: cite_images/100006304.jpg
#   inflating: cite_images/100010566.jpg
#   inflating: cite_images/100082004.jpg
#   inflating: cite_images/100008329.jpg
#   inflating: cite_images/100056533.jpg
#   inflating: cite_images/100067936.jpg
#   inflating: cite_images/100059600.jpg
#   inflating: cite_images/100021963.jpg
#   inflating: cite_images/100095578.jpg
#   inflating: cite_images/100046720.jpg
#   inflating: cite_images/100078816.jpg
#   inflating: cite_images/100104261.jpg
#   inflating: cite_images/100092217.jpg
#   inflating: cite_images/100000775.jpg
#   inflating: cite_images/100049413.jpg
#   inflating: cite_images/100017209.jpg
#   inflating: cite_images/100014700.jpg
#   inflating: cite_images/100043880.jpg
#   inflating: cite_images/100086262.jpg
#   inflating: cite_images/100052755.jpg
#   inflating: cite_images/100089151.jpg
#   inflating: cite_images/100072485.jpg
#   inflating: cite_images/100107768.jpg
#   inflating: cite_images/100045229.jpg
#   inflating: cite_images/100042546.jpg
#   inflating: cite_images/100096071.jpg
#   inflating: cite_images/100100007.jpg
#   inflating: cite_images/100004513.jpg
#   inflating: cite_images/100035916.jpg
#   inflating: cite_images/100062696.jpg
#   inflating: cite_images/100099342.jpg
#   inflating: cite_images/100073943.jpg
#   inflating: cite_images/100101319.jpg
#   inflating: cite_images/100043658.jpg
#   inflating: cite_images/100012371.jpg
#   inflating: cite_images/100063588.jpg
#   inflating: cite_images/100080613.jpg
#   inflating: cite_images/100054324.jpg
#   inflating: cite_images/100044137.jpg
#   inflating: cite_images/100106476.jpg
#   inflating: cite_images/100090400.jpg
#   inflating: cite_images/100002162.jpg
#   inflating: cite_images/100109023.jpg
#   inflating: cite_images/100015378.jpg
#   inflating: cite_images/100064581.jpg
#   inflating: cite_images/100106310.jpg
#   inflating: cite_images/100090366.jpg
#   inflating: cite_images/100055984.jpg
#   inflating: cite_images/100044651.jpg
#   inflating: cite_images/100088529.jpg
#   inflating: cite_images/100002604.jpg
#   inflating: cite_images/100074792.jpg
#   inflating: cite_images/100065847.jpg
#   inflating: cite_images/100023812.jpg
#   inflating: cite_images/100097409.jpg
#   inflating: cite_images/100012417.jpg
#   inflating: cite_images/100054442.jpg
#   inflating: cite_images/100080175.jpg
#   inflating: cite_images/100096717.jpg
#   inflating: cite_images/100100761.jpg
#   inflating: cite_images/100042220.jpg
#   inflating: cite_images/100004275.jpg
#   inflating: cite_images/100044889.jpg
#   inflating: cite_images/100099424.jpg
#   inflating: cite_images/100013709.jpg
#   inflating: cite_images/100014066.jpg
#   inflating: cite_images/100052033.jpg
#   inflating: cite_images/100086504.jpg
#   inflating: cite_images/100089637.jpg
#   inflating: cite_images/100091078.jpg
#   inflating: cite_images/100009989.jpg
#   inflating: cite_images/100104507.jpg
#   inflating: cite_images/100092571.jpg
#   inflating: cite_images/100046046.jpg
#   inflating: cite_images/100000013.jpg
#   inflating: cite_images/100049375.jpg
#   inflating: cite_images/100066396.jpg
#   inflating: cite_images/100010200.jpg
#   inflating: cite_images/100056255.jpg
#   inflating: cite_images/100082762.jpg
#   inflating: cite_images/100059166.jpg
#   inflating: cite_images/100076185.jpg
#   inflating: cite_images/100041729.jpg
#   inflating: cite_images/100103268.jpg
#   inflating: cite_images/100037867.jpg
#   inflating: cite_images/100018884.jpg
#   inflating: cite_images/100009751.jpg
#   inflating: cite_images/100071832.jpg
#   inflating: cite_images/100094100.jpg
#   inflating: cite_images/100102176.jpg
#   inflating: cite_images/100040437.jpg
#   inflating: cite_images/100006462.jpg
#   inflating: cite_images/100029481.jpg
#   inflating: cite_images/100058278.jpg
#   inflating: cite_images/100047358.jpg
#   inflating: cite_images/100019542.jpg
#   inflating: cite_images/100105619.jpg
#   inflating: cite_images/100067088.jpg
#   inflating: cite_images/100016671.jpg
#   inflating: cite_images/100039692.jpg
#   inflating: cite_images/100028947.jpg
#   inflating: cite_images/100050624.jpg
#   inflating: cite_images/100084313.jpg
#   inflating: cite_images/100000007.jpg
#   inflating: cite_images/100046052.jpg
#   inflating: cite_images/100018648.jpg
#   inflating: cite_images/100092565.jpg
#   inflating: cite_images/100104513.jpg
#   inflating: cite_images/100066382.jpg
#   inflating: cite_images/100049361.jpg
#   inflating: cite_images/100038598.jpg
#   inflating: cite_images/100085019.jpg
#   inflating: cite_images/100082776.jpg
#   inflating: cite_images/100056241.jpg
#   inflating: cite_images/100010214.jpg
#   inflating: cite_images/100007768.jpg
#   inflating: cite_images/100076191.jpg
#   inflating: cite_images/100059172.jpg
#   inflating: cite_images/100071826.jpg
#   inflating: cite_images/100009745.jpg
#   inflating: cite_images/100018890.jpg
#   inflating: cite_images/100083468.jpg
#   inflating: cite_images/100037873.jpg
#   inflating: cite_images/100029495.jpg
#   inflating: cite_images/100006476.jpg
#   inflating: cite_images/100040423.jpg
#   inflating: cite_images/100102162.jpg
#   inflating: cite_images/100094114.jpg
#   inflating: cite_images/100019556.jpg
#   inflating: cite_images/100001319.jpg
#   inflating: cite_images/100084307.jpg
#   inflating: cite_images/100050630.jpg
#   inflating: cite_images/100028953.jpg
#   inflating: cite_images/100039686.jpg
#   inflating: cite_images/100016665.jpg
#   inflating: cite_images/100064595.jpg
#   inflating: cite_images/100109037.jpg
#   inflating: cite_images/100053339.jpg
#   inflating: cite_images/100002610.jpg
#   inflating: cite_images/100044645.jpg
#   inflating: cite_images/100055990.jpg
#   inflating: cite_images/100090372.jpg
#   inflating: cite_images/100106304.jpg
#   inflating: cite_images/100023806.jpg
#   inflating: cite_images/100065853.jpg
#   inflating: cite_images/100074786.jpg
#   inflating: cite_images/100080161.jpg
#   inflating: cite_images/100054456.jpg
#   inflating: cite_images/100012403.jpg
#   inflating: cite_images/100075498.jpg
#   inflating: cite_images/100004261.jpg
#   inflating: cite_images/100042234.jpg
#   inflating: cite_images/100100775.jpg
#   inflating: cite_images/100096703.jpg
#   inflating: cite_images/100099430.jpg
#   inflating: cite_images/100055748.jpg
#   inflating: cite_images/100086510.jpg
#   inflating: cite_images/100052027.jpg
#   inflating: cite_images/100108329.jpg
#   inflating: cite_images/100014072.jpg
#   inflating: cite_images/100089623.jpg
#   inflating: cite_images/100052741.jpg
#   inflating: cite_images/100086276.jpg
#   inflating: cite_images/100043894.jpg
#   inflating: cite_images/100014714.jpg
#   inflating: cite_images/100072491.jpg
#   inflating: cite_images/100003268.jpg
#   inflating: cite_images/100089145.jpg
#   inflating: cite_images/100004507.jpg
#   inflating: cite_images/100100013.jpg
#   inflating: cite_images/100096065.jpg
#   inflating: cite_images/100042552.jpg
#   inflating: cite_images/100073957.jpg
#   inflating: cite_images/100099356.jpg
#   inflating: cite_images/100062682.jpg
#   inflating: cite_images/100081519.jpg
#   inflating: cite_images/100035902.jpg
#   inflating: cite_images/100052999.jpg
#   inflating: cite_images/100005619.jpg
#   inflating: cite_images/100054330.jpg
#   inflating: cite_images/100080607.jpg
#   inflating: cite_images/100012365.jpg
#   inflating: cite_images/100098048.jpg
#   inflating: cite_images/100087168.jpg
#   inflating: cite_images/100002176.jpg
#   inflating: cite_images/100090414.jpg
#   inflating: cite_images/100106462.jpg
#   inflating: cite_images/100044123.jpg
#   inflating: cite_images/100019230.jpg
#   inflating: cite_images/100070286.jpg
#   inflating: cite_images/100050156.jpg
#   inflating: cite_images/100084461.jpg
#   inflating: cite_images/100048719.jpg
#   inflating: cite_images/100016103.jpg
#   inflating: cite_images/100060095.jpg
#   inflating: cite_images/100009023.jpg
#   inflating: cite_images/100057639.jpg
#   inflating: cite_images/100006310.jpg
#   inflating: cite_images/100102604.jpg
#   inflating: cite_images/100094672.jpg
#   inflating: cite_images/100040345.jpg
#   inflating: cite_images/100056527.jpg
#   inflating: cite_images/100082010.jpg
#   inflating: cite_images/100010572.jpg
#   inflating: cite_images/100021977.jpg
#   inflating: cite_images/100059614.jpg
#   inflating: cite_images/100067922.jpg
#   inflating: cite_images/100000761.jpg
#   inflating: cite_images/100071198.jpg
#   inflating: cite_images/100092203.jpg
#   inflating: cite_images/100104275.jpg
#   inflating: cite_images/100078802.jpg
#   inflating: cite_images/100046734.jpg
#   inflating: cite_images/100049407.jpg
#   inflating: cite_images/100051248.jpg
#   inflating: cite_images/100003240.jpg
#   inflating: cite_images/100107754.jpg
#   inflating: cite_images/100091722.jpg
#   inflating: cite_images/100045215.jpg
#   inflating: cite_images/100108467.jpg
#   inflating: cite_images/100052769.jpg
#   inflating: cite_images/100023190.jpg
#   inflating: cite_images/100055006.jpg
#   inflating: cite_images/100081531.jpg
#   inflating: cite_images/100013053.jpg
#   inflating: cite_images/100033383.jpg
#   inflating: cite_images/100098060.jpg
#   inflating: cite_images/100054318.jpg
#   inflating: cite_images/100005631.jpg
#   inflating: cite_images/100097353.jpg
#   inflating: cite_images/100101325.jpg
#   inflating: cite_images/100043664.jpg
#   inflating: cite_images/100024827.jpg
#   inflating: cite_images/100062872.jpg
#   inflating: cite_images/100088273.jpg
#   inflating: cite_images/100053477.jpg
#   inflating: cite_images/100087140.jpg
#   inflating: cite_images/100015422.jpg
#   inflating: cite_images/100076807.jpg
#   inflating: cite_images/100048731.jpg
#   inflating: cite_images/100084449.jpg
#   inflating: cite_images/100030852.jpg
#   inflating: cite_images/100021787.jpg
#   inflating: cite_images/100001457.jpg
#   inflating: cite_images/100105143.jpg
#   inflating: cite_images/100093135.jpg
#   inflating: cite_images/100047402.jpg
#   inflating: cite_images/100019218.jpg
#   inflating: cite_images/100031594.jpg
#   inflating: cite_images/100006338.jpg
#   inflating: cite_images/100058522.jpg
#   inflating: cite_images/100057611.jpg
#   inflating: cite_images/100083326.jpg
#   inflating: cite_images/100069927.jpg
#   inflating: cite_images/100011644.jpg
#   inflating: cite_images/100000991.jpg
#   inflating: cite_images/100007026.jpg
#   inflating: cite_images/100095544.jpg
#   inflating: cite_images/100103532.jpg
#   inflating: cite_images/100041073.jpg
#   inflating: cite_images/100082038.jpg
#   inflating: cite_images/100008315.jpg
#   inflating: cite_images/100020499.jpg
#   inflating: cite_images/100051260.jpg
#   inflating: cite_images/100094882.jpg
#   inflating: cite_images/100085757.jpg
#   inflating: cite_images/100017235.jpg
#   inflating: cite_images/100018106.jpg
#   inflating: cite_images/100000749.jpg
#   inflating: cite_images/100085031.jpg
#   inflating: cite_images/100051506.jpg
#   inflating: cite_images/100049349.jpg
#   inflating: cite_images/100017553.jpg
#   inflating: cite_images/100026956.jpg
#   inflating: cite_images/100069099.jpg
#   inflating: cite_images/100018660.jpg
#   inflating: cite_images/100037683.jpg
#   inflating: cite_images/100060903.jpg
#   inflating: cite_images/100007740.jpg
#   inflating: cite_images/100039876.jpg
#   inflating: cite_images/100016895.jpg
#   inflating: cite_images/100041715.jpg
#   inflating: cite_images/100095222.jpg
#   inflating: cite_images/100103254.jpg
#   inflating: cite_images/100008473.jpg
#   inflating: cite_images/100027490.jpg
#   inflating: cite_images/100056269.jpg
#   inflating: cite_images/100058244.jpg
#   inflating: cite_images/100083440.jpg
#   inflating: cite_images/100057177.jpg
#   inflating: cite_images/100078194.jpg
#   inflating: cite_images/100011122.jpg
#   inflating: cite_images/100048057.jpg
#   inflating: cite_images/100007998.jpg
#   inflating: cite_images/100050618.jpg
#   inflating: cite_images/100001331.jpg
#   inflating: cite_images/100082986.jpg
#   inflating: cite_images/100047364.jpg
#   inflating: cite_images/100068387.jpg
#   inflating: cite_images/100105625.jpg
#   inflating: cite_images/100093653.jpg
#   inflating: cite_images/100035094.jpg
#   inflating: cite_images/100088515.jpg
#   inflating: cite_images/100002638.jpg
#   inflating: cite_images/100087626.jpg
#   inflating: cite_images/100100985.jpg
#   inflating: cite_images/100053311.jpg
#   inflating: cite_images/100015344.jpg
#   inflating: cite_images/100098706.jpg
#   inflating: cite_images/100025287.jpg
#   inflating: cite_images/100080149.jpg
#   inflating: cite_images/100005157.jpg
#   inflating: cite_images/100043102.jpg
#   inflating: cite_images/100097435.jpg
#   inflating: cite_images/100101443.jpg
#   inflating: cite_images/100081257.jpg
#   inflating: cite_images/100055760.jpg
#   inflating: cite_images/100024199.jpg
#   inflating: cite_images/100099418.jpg
#   inflating: cite_images/100013735.jpg
#   inflating: cite_images/100004249.jpg
#   inflating: cite_images/100003526.jpg
#   inflating: cite_images/100045573.jpg
#   inflating: cite_images/100107032.jpg
#   inflating: cite_images/100091044.jpg
#   inflating: cite_images/100074976.jpg
#   inflating: cite_images/100108301.jpg
#   inflating: cite_images/100086538.jpg
#   inflating: cite_images/100032923.jpg
#   inflating: cite_images/100088501.jpg
#   inflating: cite_images/100035080.jpg
#   inflating: cite_images/100044679.jpg
#   inflating: cite_images/100106338.jpg
#   inflating: cite_images/100015350.jpg
#   inflating: cite_images/100053305.jpg
#   inflating: cite_images/100100991.jpg
#   inflating: cite_images/100087632.jpg
#   inflating: cite_images/100025293.jpg
#   inflating: cite_images/100098712.jpg
#   inflating: cite_images/100101457.jpg
#   inflating: cite_images/100097421.jpg
#   inflating: cite_images/100043116.jpg
#   inflating: cite_images/100005143.jpg
#   inflating: cite_images/100013721.jpg
#   inflating: cite_images/100055774.jpg
#   inflating: cite_images/100081243.jpg
#   inflating: cite_images/100042208.jpg
#   inflating: cite_images/100100749.jpg
#   inflating: cite_images/100091050.jpg
#   inflating: cite_images/100107026.jpg
#   inflating: cite_images/100045567.jpg
#   inflating: cite_images/100003532.jpg
#   inflating: cite_images/100032937.jpg
#   inflating: cite_images/100108315.jpg
#   inflating: cite_images/100074962.jpg
#   inflating: cite_images/100017547.jpg
#   inflating: cite_images/100051512.jpg
#   inflating: cite_images/100085025.jpg
#   inflating: cite_images/100060917.jpg
#   inflating: cite_images/100037697.jpg
#   inflating: cite_images/100018674.jpg
#   inflating: cite_images/100026942.jpg
#   inflating: cite_images/100092559.jpg
#   inflating: cite_images/100103240.jpg
#   inflating: cite_images/100095236.jpg
#   inflating: cite_images/100041701.jpg
#   inflating: cite_images/100016881.jpg
#   inflating: cite_images/100039862.jpg
#   inflating: cite_images/100007754.jpg
#   inflating: cite_images/100027484.jpg
#   inflating: cite_images/100008467.jpg
#   inflating: cite_images/100010228.jpg
#   inflating: cite_images/100058250.jpg
#   inflating: cite_images/100094128.jpg
#   inflating: cite_images/100011136.jpg
#   inflating: cite_images/100009779.jpg
#   inflating: cite_images/100078180.jpg
#   inflating: cite_images/100057163.jpg
#   inflating: cite_images/100083454.jpg
#   inflating: cite_images/100048043.jpg
#   inflating: cite_images/100016659.jpg
#   inflating: cite_images/100093647.jpg
#   inflating: cite_images/100105631.jpg
#   inflating: cite_images/100068393.jpg
#   inflating: cite_images/100047370.jpg
#   inflating: cite_images/100082992.jpg
#   inflating: cite_images/100036589.jpg
#   inflating: cite_images/100001325.jpg
#   inflating: cite_images/100021793.jpg
#   inflating: cite_images/100030846.jpg
#   inflating: cite_images/100048725.jpg
#   inflating: cite_images/100076813.jpg
#   inflating: cite_images/100047416.jpg
#   inflating: cite_images/100093121.jpg
#   inflating: cite_images/100105157.jpg
#   inflating: cite_images/100001443.jpg
#   inflating: cite_images/100058536.jpg
#   inflating: cite_images/100102638.jpg
#   inflating: cite_images/100040379.jpg
#   inflating: cite_images/100031580.jpg
#   inflating: cite_images/100000985.jpg
#   inflating: cite_images/100011650.jpg
#   inflating: cite_images/100069933.jpg
#   inflating: cite_images/100083332.jpg
#   inflating: cite_images/100057605.jpg
#   inflating: cite_images/100041067.jpg
#   inflating: cite_images/100103526.jpg
#   inflating: cite_images/100095550.jpg
#   inflating: cite_images/100007032.jpg
#   inflating: cite_images/100059628.jpg
#   inflating: cite_images/100008301.jpg
#   inflating: cite_images/100017221.jpg
#   inflating: cite_images/100085743.jpg
#   inflating: cite_images/100094896.jpg
#   inflating: cite_images/100051274.jpg
#   inflating: cite_images/100011888.jpg
#   inflating: cite_images/100104249.jpg
#   inflating: cite_images/100046708.jpg
#   inflating: cite_images/100018112.jpg
#   inflating: cite_images/100045201.jpg
#   inflating: cite_images/100091736.jpg
#   inflating: cite_images/100107740.jpg
#   inflating: cite_images/100003254.jpg
#   inflating: cite_images/100089179.jpg
#   inflating: cite_images/100023184.jpg
#   inflating: cite_images/100014728.jpg
#   inflating: cite_images/100108473.jpg
#   inflating: cite_images/100013047.jpg
#   inflating: cite_images/100081525.jpg
#   inflating: cite_images/100055012.jpg
#   inflating: cite_images/100096059.jpg
#   inflating: cite_images/100033397.jpg
#   inflating: cite_images/100107998.jpg
#   inflating: cite_images/100012359.jpg
#   inflating: cite_images/100098074.jpg
#   inflating: cite_images/100032089.jpg
#   inflating: cite_images/100043670.jpg
#   inflating: cite_images/100101331.jpg
#   inflating: cite_images/100097347.jpg
#   inflating: cite_images/100005625.jpg
#   inflating: cite_images/100088267.jpg
#   inflating: cite_images/100062866.jpg
#   inflating: cite_images/100024833.jpg
#   inflating: cite_images/100090428.jpg
#   inflating: cite_images/100015436.jpg
#   inflating: cite_images/100087154.jpg
#   inflating: cite_images/100053463.jpg
#   inflating: cite_images/100003903.jpg
#   inflating: cite_images/100045956.jpg
#   inflating: cite_images/100054683.jpg
#   inflating: cite_images/100074553.jpg
#   inflating: cite_images/100032506.jpg
#   inflating: cite_images/100044490.jpg
#   inflating: cite_images/100035269.jpg
#   inflating: cite_images/100022715.jpg
#   inflating: cite_images/100064740.jpg
#   inflating: cite_images/100075895.jpg
#   inflating: cite_images/100072122.jpg
#   inflating: cite_images/100034177.jpg
#   inflating: cite_images/100097810.jpg
#   inflating: cite_images/100101866.jpg
#   inflating: cite_images/100024364.jpg
#   inflating: cite_images/100062331.jpg
#   inflating: cite_images/100088930.jpg
#   inflating: cite_images/100033618.jpg
#   inflating: cite_images/100064998.jpg
#   inflating: cite_images/100076344.jpg
#   inflating: cite_images/100030311.jpg
#   inflating: cite_images/100061638.jpg
#   inflating: cite_images/100056094.jpg
#   inflating: cite_images/100079077.jpg
#   inflating: cite_images/100020102.jpg
#   inflating: cite_images/100066157.jpg
#   inflating: cite_images/100029898.jpg
#   inflating: cite_images/100046287.jpg
#   inflating: cite_images/100083865.jpg
#   inflating: cite_images/100069264.jpg
#   inflating: cite_images/100039453.jpg
#   inflating: cite_images/100067249.jpg
#   inflating: cite_images/100070735.jpg
#   inflating: cite_images/100008856.jpg
#   inflating: cite_images/100019783.jpg
#   inflating: cite_images/100036760.jpg
#   inflating: cite_images/100047199.jpg
#   inflating: cite_images/100051923.jpg
#   inflating: cite_images/100029640.jpg
#   inflating: cite_images/100038995.jpg
#   inflating: cite_images/100017976.jpg
#   inflating: cite_images/100078369.jpg
#   inflating: cite_images/100009590.jpg
#   inflating: cite_images/100092968.jpg
#   inflating: cite_images/100026573.jpg
#   inflating: cite_images/100060526.jpg
#   inflating: cite_images/100031769.jpg
#   inflating: cite_images/100040190.jpg
#   inflating: cite_images/100029126.jpg
#   inflating: cite_images/100026215.jpg
#   inflating: cite_images/100060240.jpg
#   inflating: cite_images/100039335.jpg
#   inflating: cite_images/100095961.jpg
#   inflating: cite_images/100050383.jpg
#   inflating: cite_images/100103917.jpg
#   inflating: cite_images/100070053.jpg
#   inflating: cite_images/100036006.jpg
#   inflating: cite_images/100020664.jpg
#   inflating: cite_images/100058907.jpg
#   inflating: cite_images/100066631.jpg
#   inflating: cite_images/100037318.jpg
#   inflating: cite_images/100069502.jpg
#   inflating: cite_images/100076422.jpg
#   inflating: cite_images/100028238.jpg
#   inflating: cite_images/100030477.jpg
#   inflating: cite_images/100001872.jpg
#   inflating: cite_images/100079711.jpg
#   inflating: cite_images/100047827.jpg
#   inflating: cite_images/100090819.jpg
#   inflating: cite_images/100024402.jpg
#   inflating: cite_images/100099183.jpg
#   inflating: cite_images/100062457.jpg
#   inflating: cite_images/100053852.jpg
#   inflating: cite_images/100042787.jpg
#   inflating: cite_images/100015807.jpg
#   inflating: cite_images/100072644.jpg
#   inflating: cite_images/100063991.jpg
#   inflating: cite_images/100089390.jpg
#   inflating: cite_images/100034611.jpg
#   inflating: cite_images/100065338.jpg
#   inflating: cite_images/100052594.jpg
#   inflating: cite_images/100081914.jpg
#   inflating: cite_images/100022073.jpg
#   inflating: cite_images/100064026.jpg
#   inflating: cite_images/100063749.jpg
#   inflating: cite_images/100074235.jpg
#   inflating: cite_images/100108842.jpg
#   inflating: cite_images/100043499.jpg
#   inflating: cite_images/100032260.jpg
#   inflating: cite_images/100062443.jpg
#   inflating: cite_images/100099197.jpg
#   inflating: cite_images/100024416.jpg
#   inflating: cite_images/100015813.jpg
#   inflating: cite_images/100042793.jpg
#   inflating: cite_images/100053846.jpg
#   inflating: cite_images/100034605.jpg
#   inflating: cite_images/100089384.jpg
#   inflating: cite_images/100063985.jpg
#   inflating: cite_images/100072650.jpg
#   inflating: cite_images/100023379.jpg
#   inflating: cite_images/100052580.jpg
#   inflating: cite_images/100081900.jpg
#   inflating: cite_images/100064032.jpg
#   inflating: cite_images/100022067.jpg
#   inflating: cite_images/100025708.jpg
#   inflating: cite_images/100072888.jpg
#   inflating: cite_images/100098289.jpg
#   inflating: cite_images/100032274.jpg
#   inflating: cite_images/100108856.jpg
#   inflating: cite_images/100074221.jpg
#   inflating: cite_images/100077728.jpg
#   inflating: cite_images/100029132.jpg
#   inflating: cite_images/100040184.jpg
#   inflating: cite_images/100060254.jpg
#   inflating: cite_images/100026201.jpg
#   inflating: cite_images/100103903.jpg
#   inflating: cite_images/100050397.jpg
#   inflating: cite_images/100095975.jpg
#   inflating: cite_images/100039321.jpg
#   inflating: cite_images/100036012.jpg
#   inflating: cite_images/100068608.jpg
#   inflating: cite_images/100070047.jpg
#   inflating: cite_images/100066625.jpg
#   inflating: cite_images/100058913.jpg
#   inflating: cite_images/100051089.jpg
#   inflating: cite_images/100020670.jpg
#   inflating: cite_images/100071359.jpg
#   inflating: cite_images/100069516.jpg
#   inflating: cite_images/100030463.jpg
#   inflating: cite_images/100084878.jpg
#   inflating: cite_images/100076436.jpg
#   inflating: cite_images/100047833.jpg
#   inflating: cite_images/100079705.jpg
#   inflating: cite_images/100001866.jpg
#   inflating: cite_images/100030305.jpg
#   inflating: cite_images/100076350.jpg
#   inflating: cite_images/100079063.jpg
#   inflating: cite_images/100056080.jpg
#   inflating: cite_images/100027679.jpg
#   inflating: cite_images/100038759.jpg
#   inflating: cite_images/100066143.jpg
#   inflating: cite_images/100020116.jpg
#   inflating: cite_images/100018489.jpg
#   inflating: cite_images/100069270.jpg
#   inflating: cite_images/100083871.jpg
#   inflating: cite_images/100046293.jpg
#   inflating: cite_images/100021208.jpg
#   inflating: cite_images/100039447.jpg
#   inflating: cite_images/100036774.jpg
#   inflating: cite_images/100019797.jpg
#   inflating: cite_images/100008842.jpg
#   inflating: cite_images/100070721.jpg
#   inflating: cite_images/100017962.jpg
#   inflating: cite_images/100038981.jpg
#   inflating: cite_images/100029654.jpg
#   inflating: cite_images/100051937.jpg
#   inflating: cite_images/100060532.jpg
#   inflating: cite_images/100026567.jpg
#   inflating: cite_images/100009584.jpg
#   inflating: cite_images/100054697.jpg
#   inflating: cite_images/100045942.jpg
#   inflating: cite_images/100003917.jpg
#   inflating: cite_images/100032512.jpg
#   inflating: cite_images/100086909.jpg
#   inflating: cite_images/100074547.jpg
#   inflating: cite_images/100073228.jpg
#   inflating: cite_images/100099829.jpg
#   inflating: cite_images/100044484.jpg
#   inflating: cite_images/100075881.jpg
#   inflating: cite_images/100064754.jpg
#   inflating: cite_images/100022701.jpg
#   inflating: cite_images/100034163.jpg
#   inflating: cite_images/100072136.jpg
#   inflating: cite_images/100101872.jpg
#   inflating: cite_images/100097804.jpg
#   inflating: cite_images/100088924.jpg
#   inflating: cite_images/100062325.jpg
#   inflating: cite_images/100024370.jpg
#   inflating: cite_images/100055589.jpg
#   inflating: cite_images/100075659.jpg
#   inflating: cite_images/100061604.jpg
#   inflating: cite_images/100036984.jpg
#   inflating: cite_images/100019967.jpg
#   inflating: cite_images/100027651.jpg
#   inflating: cite_images/100076378.jpg
#   inflating: cite_images/100007581.jpg
#   inflating: cite_images/100028562.jpg
#   inflating: cite_images/100103095.jpg
#   inflating: cite_images/100037442.jpg
#   inflating: cite_images/100083859.jpg
#   inflating: cite_images/100069258.jpg
#   inflating: cite_images/100071417.jpg
#   inflating: cite_images/100040812.jpg
#   inflating: cite_images/100017792.jpg
#   inflating: cite_images/100038771.jpg
#   inflating: cite_images/100049188.jpg
#   inflating: cite_images/100006847.jpg
#   inflating: cite_images/100070709.jpg
#   inflating: cite_images/100093492.jpg
#   inflating: cite_images/100027889.jpg
#   inflating: cite_images/100068146.jpg
#   inflating: cite_images/100048296.jpg
#   inflating: cite_images/100067275.jpg
#   inflating: cite_images/100021220.jpg
#   inflating: cite_images/100078355.jpg
#   inflating: cite_images/100104922.jpg
#   inflating: cite_images/100092954.jpg
#   inflating: cite_images/100083681.jpg
#   inflating: cite_images/100031033.jpg
#   inflating: cite_images/100058085.jpg
#   inflating: cite_images/100077066.jpg
#   inflating: cite_images/100005396.jpg
#   inflating: cite_images/100101682.jpg
#   inflating: cite_images/100086921.jpg
#   inflating: cite_images/100063013.jpg
#   inflating: cite_images/100080388.jpg
#   inflating: cite_images/100025046.jpg
#   inflating: cite_images/100022729.jpg
#   inflating: cite_images/100015185.jpg
#   inflating: cite_images/100035255.jpg
#   inflating: cite_images/100099801.jpg
#   inflating: cite_images/100073200.jpg
#   inflating: cite_images/100065462.jpg
#   inflating: cite_images/100023437.jpg
#   inflating: cite_images/100012832.jpg
#   inflating: cite_images/100054867.jpg
#   inflating: cite_images/100091285.jpg
#   inflating: cite_images/100033624.jpg
#   inflating: cite_images/100004088.jpg
#   inflating: cite_images/100075671.jpg
#   inflating: cite_images/100024358.jpg
#   inflating: cite_images/100081096.jpg
#   inflating: cite_images/100033142.jpg
#   inflating: cite_images/100075117.jpg
#   inflating: cite_images/100106853.jpg
#   inflating: cite_images/100090825.jpg
#   inflating: cite_images/100013292.jpg
#   inflating: cite_images/100065304.jpg
#   inflating: cite_images/100023351.jpg
#   inflating: cite_images/100003081.jpg
#   inflating: cite_images/100072678.jpg
#   inflating: cite_images/100107595.jpg
#   inflating: cite_images/100087381.jpg
#   inflating: cite_images/100042963.jpg
#   inflating: cite_images/100004936.jpg
#   inflating: cite_images/100035533.jpg
#   inflating: cite_images/100081928.jpg
#   inflating: cite_images/100073566.jpg
#   inflating: cite_images/100074209.jpg
#   inflating: cite_images/100097192.jpg
#   inflating: cite_images/100063775.jpg
#   inflating: cite_images/100025720.jpg
#   inflating: cite_images/100078433.jpg
#   inflating: cite_images/100026229.jpg
#   inflating: cite_images/100011485.jpg
#   inflating: cite_images/100020880.jpg
#   inflating: cite_images/100031755.jpg
#   inflating: cite_images/100049836.jpg
#   inflating: cite_images/100077700.jpg
#   inflating: cite_images/100001696.jpg
#   inflating: cite_images/100010943.jpg
#   inflating: cite_images/100068620.jpg
#   inflating: cite_images/100056916.jpg
#   inflating: cite_images/100105382.jpg
#   inflating: cite_images/100039309.jpg
#   inflating: cite_images/100067513.jpg
#   inflating: cite_images/100021546.jpg
#   inflating: cite_images/100084688.jpg
#   inflating: cite_images/100037324.jpg
#   inflating: cite_images/100071371.jpg
#   inflating: cite_images/100000588.jpg
#   inflating: cite_images/100085596.jpg
#   inflating: cite_images/100020658.jpg
#   inflating: cite_images/100038017.jpg
#   inflating: cite_images/100061162.jpg
#   inflating: cite_images/100027137.jpg
#   inflating: cite_images/100028204.jpg
#   inflating: cite_images/100084850.jpg
#   inflating: cite_images/100095785.jpg
#   inflating: cite_images/100011491.jpg
#   inflating: cite_images/100060268.jpg
#   inflating: cite_images/100078427.jpg
#   inflating: cite_images/100077714.jpg
#   inflating: cite_images/100049822.jpg
#   inflating: cite_images/100031741.jpg
#   inflating: cite_images/100020894.jpg
#   inflating: cite_images/100105396.jpg
#   inflating: cite_images/100056902.jpg
#   inflating: cite_images/100068634.jpg
#   inflating: cite_images/100010957.jpg
#   inflating: cite_images/100001682.jpg
#   inflating: cite_images/100095949.jpg
#   inflating: cite_images/100021552.jpg
#   inflating: cite_images/100067507.jpg
#   inflating: cite_images/100071365.jpg
#   inflating: cite_images/100037330.jpg
#   inflating: cite_images/100104088.jpg
#   inflating: cite_images/100038003.jpg
#   inflating: cite_images/100066619.jpg
#   inflating: cite_images/100031999.jpg
#   inflating: cite_images/100085582.jpg
#   inflating: cite_images/100079739.jpg
#   inflating: cite_images/100027123.jpg
#   inflating: cite_images/100061176.jpg
#   inflating: cite_images/100095791.jpg
#   inflating: cite_images/100084844.jpg
#   inflating: cite_images/100028210.jpg
#   inflating: cite_images/100075103.jpg
#   inflating: cite_images/100033156.jpg
#   inflating: cite_images/100096298.jpg
#   inflating: cite_images/100013286.jpg
#   inflating: cite_images/100090831.jpg
#   inflating: cite_images/100106847.jpg
#   inflating: cite_images/100023345.jpg
#   inflating: cite_images/100065310.jpg
#   inflating: cite_images/100107581.jpg
#   inflating: cite_images/100034639.jpg
#   inflating: cite_images/100003095.jpg
#   inflating: cite_images/100004922.jpg
#   inflating: cite_images/100042977.jpg
#   inflating: cite_images/100087395.jpg
#   inflating: cite_images/100073572.jpg
#   inflating: cite_images/100035527.jpg
#   inflating: cite_images/100097186.jpg
#   inflating: cite_images/100032248.jpg
#   inflating: cite_images/100025734.jpg
#   inflating: cite_images/100063761.jpg
#   inflating: cite_images/100012198.jpg
#   inflating: cite_images/100086935.jpg
#   inflating: cite_images/100101696.jpg
#   inflating: cite_images/100005382.jpg
#   inflating: cite_images/100025052.jpg
#   inflating: cite_images/100063007.jpg
#   inflating: cite_images/100064768.jpg
#   inflating: cite_images/100015191.jpg
#   inflating: cite_images/100073214.jpg
#   inflating: cite_images/100099815.jpg
#   inflating: cite_images/100035241.jpg
#   inflating: cite_images/100097838.jpg
#   inflating: cite_images/100023423.jpg
#   inflating: cite_images/100065476.jpg
#   inflating: cite_images/100091291.jpg
#   inflating: cite_images/100054873.jpg
#   inflating: cite_images/100012826.jpg
#   inflating: cite_images/100075665.jpg
#   inflating: cite_images/100100588.jpg
#   inflating: cite_images/100033630.jpg
#   inflating: cite_images/100088918.jpg
#   inflating: cite_images/100062319.jpg
#   inflating: cite_images/100081082.jpg
#   inflating: cite_images/100027645.jpg
#   inflating: cite_images/100019973.jpg
#   inflating: cite_images/100036990.jpg
#   inflating: cite_images/100061610.jpg
#   inflating: cite_images/100030339.jpg
#   inflating: cite_images/100103081.jpg
#   inflating: cite_images/100028576.jpg
#   inflating: cite_images/100007595.jpg
#   inflating: cite_images/100071403.jpg
#   inflating: cite_images/100092798.jpg
#   inflating: cite_images/100037456.jpg
#   inflating: cite_images/100006853.jpg
#   inflating: cite_images/100038765.jpg
#   inflating: cite_images/100017786.jpg
#   inflating: cite_images/100040806.jpg
#   inflating: cite_images/100036748.jpg
#   inflating: cite_images/100068152.jpg
#   inflating: cite_images/100093486.jpg
#   inflating: cite_images/100021234.jpg
#   inflating: cite_images/100016498.jpg
#   inflating: cite_images/100067261.jpg
#   inflating: cite_images/100048282.jpg
#   inflating: cite_images/100083695.jpg
#   inflating: cite_images/100092940.jpg
#   inflating: cite_images/100104936.jpg
#   inflating: cite_images/100078341.jpg
#   inflating: cite_images/100077072.jpg
#   inflating: cite_images/100058091.jpg
#   inflating: cite_images/100029668.jpg
# ...
#   inflating: cite_images/100014477.jpg
#   inflating: cite_images/100052422.jpg
#   inflating: cite_images/100086115.jpg
#   inflating: cite_images/100089226.jpg
#   inflating: cite_images/100063827.jpg
#   inflating: cite_images/100091469.jpg
#   inflating: cite_images/100025872.jpg
#   inflating: cite_images/100090944.jpg
#   inflating: cite_images/100106932.jpg
#   inflating: cite_images/100081691.jpg
#   inflating: cite_images/100033023.jpg
#   inflating: cite_images/100075076.jpg
#   inflating: cite_images/100072719.jpg
#   inflating: cite_images/100025899.jpg
#   inflating: cite_images/100091482.jpg
#   inflating: cite_images/100065265.jpg
#   inflating: cite_images/100023230.jpg
#   inflating: cite_images/100081849.jpg
#   inflating: cite_images/100035452.jpg
#   inflating: cite_images/100073407.jpg
#   inflating: cite_images/100042802.jpg
#   inflating: cite_images/100015782.jpg
#   inflating: cite_images/100004857.jpg
#   inflating: cite_images/100063614.jpg
#   inflating: cite_images/100034994.jpg
#   inflating: cite_images/100025641.jpg
#   inflating: cite_images/100005591.jpg
#   inflating: cite_images/100074368.jpg
#   inflating: cite_images/100101085.jpg
#   inflating: cite_images/100031634.jpg
#   inflating: cite_images/100077661.jpg
#   inflating: cite_images/100006098.jpg
#   inflating: cite_images/100058682.jpg
#   inflating: cite_images/100049957.jpg
#   inflating: cite_images/100026348.jpg
#   inflating: cite_images/100078552.jpg
#   inflating: cite_images/100083086.jpg
#   inflating: cite_images/100067472.jpg
#   inflating: cite_images/100039268.jpg
#   inflating: cite_images/100048491.jpg
#   inflating: cite_images/100021427.jpg
#   inflating: cite_images/100010822.jpg
#   inflating: cite_images/100056877.jpg
#   inflating: cite_images/100093295.jpg
#   inflating: cite_images/100079894.jpg
#   inflating: cite_images/100068741.jpg
#   inflating: cite_images/100020739.jpg
#   inflating: cite_images/100038176.jpg
#   inflating: cite_images/100017195.jpg
#   inflating: cite_images/100037245.jpg
#   inflating: cite_images/100071210.jpg
#   inflating: cite_images/100028365.jpg
#   inflating: cite_images/100007386.jpg
#   inflating: cite_images/100103692.jpg
#   inflating: cite_images/100084931.jpg
#   inflating: cite_images/100061003.jpg
#   inflating: cite_images/100068999.jpg
#   inflating: cite_images/100082398.jpg
#   inflating: cite_images/100027056.jpg
#   inflating: cite_images/100028403.jpg
#   inflating: cite_images/100076219.jpg
#   inflating: cite_images/100095182.jpg
#   inflating: cite_images/100061765.jpg
#   inflating: cite_images/100027730.jpg
#   inflating: cite_images/100019806.jpg
#   inflating: cite_images/100085391.jpg
#   inflating: cite_images/100040973.jpg
#   inflating: cite_images/100006926.jpg
#   inflating: cite_images/100038610.jpg
#   inflating: cite_images/100069339.jpg
#   inflating: cite_images/100083938.jpg
#   inflating: cite_images/100037523.jpg
#   inflating: cite_images/100071576.jpg
#   inflating: cite_images/100067314.jpg
#   inflating: cite_images/100021341.jpg
#   inflating: cite_images/100070668.jpg
#   inflating: cite_images/100001091.jpg
#   inflating: cite_images/100068027.jpg
#   inflating: cite_images/100105585.jpg
#   inflating: cite_images/100031152.jpg
#   inflating: cite_images/100077107.jpg
#   inflating: cite_images/100092835.jpg
#   inflating: cite_images/100104843.jpg
#   inflating: cite_images/100078234.jpg
#   inflating: cite_images/100011282.jpg
#   inflating: cite_images/100063172.jpg
#   inflating: cite_images/100025127.jpg
#   inflating: cite_images/100086840.jpg
#   inflating: cite_images/100097795.jpg
#   inflating: cite_images/100035334.jpg
#   inflating: cite_images/100002598.jpg
#   inflating: cite_images/100073361.jpg
#   inflating: cite_images/100099960.jpg
#   inflating: cite_images/100087586.jpg
#   inflating: cite_images/100022648.jpg
#   inflating: cite_images/100003686.jpg
#   inflating: cite_images/100012953.jpg
#   inflating: cite_images/100107392.jpg
#   inflating: cite_images/100054906.jpg
#   inflating: cite_images/100065503.jpg
#   inflating: cite_images/100023556.jpg
#   inflating: cite_images/100086698.jpg
#   inflating: cite_images/100024239.jpg
#   inflating: cite_images/100013495.jpg
#   inflating: cite_images/100022890.jpg
#   inflating: cite_images/100033745.jpg
#   inflating: cite_images/100075710.jpg
#   inflating: cite_images/100025133.jpg
#   inflating: cite_images/100063166.jpg
#   inflating: cite_images/100097781.jpg
#   inflating: cite_images/100086854.jpg
#   inflating: cite_images/100099974.jpg
#   inflating: cite_images/100073375.jpg
#   inflating: cite_images/100035320.jpg
#   inflating: cite_images/100106098.jpg
#   inflating: cite_images/100064609.jpg
#   inflating: cite_images/100087592.jpg
#   inflating: cite_images/100033989.jpg
#   inflating: cite_images/100054912.jpg
#   inflating: cite_images/100107386.jpg
#   inflating: cite_images/100012947.jpg
#   inflating: cite_images/100003692.jpg
#   inflating: cite_images/100023542.jpg
#   inflating: cite_images/100097959.jpg
#   inflating: cite_images/100065517.jpg
#   inflating: cite_images/100062278.jpg
#   inflating: cite_images/100013481.jpg
#   inflating: cite_images/100088879.jpg
#   inflating: cite_images/100075704.jpg
#   inflating: cite_images/100033751.jpg
#   inflating: cite_images/100022884.jpg
#   inflating: cite_images/100095196.jpg
#   inflating: cite_images/100030258.jpg
#   inflating: cite_images/100028417.jpg
#   inflating: cite_images/100019812.jpg
#   inflating: cite_images/100027724.jpg
#   inflating: cite_images/100010188.jpg
#   inflating: cite_images/100061771.jpg
#   inflating: cite_images/100038604.jpg
#   inflating: cite_images/100006932.jpg
#   inflating: cite_images/100040967.jpg
#   inflating: cite_images/100085385.jpg
#   inflating: cite_images/100071562.jpg
#   inflating: cite_images/100037537.jpg
#   inflating: cite_images/100021355.jpg
#   inflating: cite_images/100067300.jpg
#   inflating: cite_images/100105591.jpg
#   inflating: cite_images/100068033.jpg
#   inflating: cite_images/100036629.jpg
#   inflating: cite_images/100001085.jpg
#   inflating: cite_images/100029709.jpg
#   inflating: cite_images/100077113.jpg
#   inflating: cite_images/100031146.jpg
#   inflating: cite_images/100094288.jpg
#   inflating: cite_images/100011296.jpg
#   inflating: cite_images/100078220.jpg
#   inflating: cite_images/100104857.jpg
#   inflating: cite_images/100092821.jpg
#   inflating: cite_images/100049943.jpg
#   inflating: cite_images/100058696.jpg
#   inflating: cite_images/100077675.jpg
#   inflating: cite_images/100102598.jpg
#   inflating: cite_images/100031620.jpg
#   inflating: cite_images/100060309.jpg
#   inflating: cite_images/100083092.jpg
#   inflating: cite_images/100078546.jpg
#   inflating: cite_images/100021433.jpg
#   inflating: cite_images/100095828.jpg
#   inflating: cite_images/100048485.jpg
#   inflating: cite_images/100067466.jpg
#   inflating: cite_images/100068755.jpg
#   inflating: cite_images/100079880.jpg
#   inflating: cite_images/100093281.jpg
#   inflating: cite_images/100056863.jpg
#   inflating: cite_images/100010836.jpg
#   inflating: cite_images/100017181.jpg
#   inflating: cite_images/100066778.jpg
#   inflating: cite_images/100038162.jpg
#   inflating: cite_images/100071204.jpg
#   inflating: cite_images/100037251.jpg
#   inflating: cite_images/100084925.jpg
#   inflating: cite_images/100103686.jpg
#   inflating: cite_images/100007392.jpg
#   inflating: cite_images/100059588.jpg
#   inflating: cite_images/100028371.jpg
#   inflating: cite_images/100027042.jpg
#   inflating: cite_images/100079658.jpg
#   inflating: cite_images/100061017.jpg
#   inflating: cite_images/100081685.jpg
#   inflating: cite_images/100106926.jpg
#   inflating: cite_images/100090950.jpg
#   inflating: cite_images/100075062.jpg
#   inflating: cite_images/100033037.jpg
#   inflating: cite_images/100034758.jpg
#   inflating: cite_images/100091496.jpg
#   inflating: cite_images/100023224.jpg
#   inflating: cite_images/100065271.jpg
#   inflating: cite_images/100014488.jpg
#   inflating: cite_images/100073413.jpg
#   inflating: cite_images/100090788.jpg
#   inflating: cite_images/100035446.jpg
#   inflating: cite_images/100004843.jpg
#   inflating: cite_images/100015796.jpg
#   inflating: cite_images/100042816.jpg
#   inflating: cite_images/100025655.jpg
#   inflating: cite_images/100034980.jpg
#   inflating: cite_images/100063600.jpg
#   inflating: cite_images/100032329.jpg
#   inflating: cite_images/100101091.jpg
#   inflating: cite_images/100005585.jpg
#   inflating: cite_images/100026374.jpg
#   inflating: cite_images/100009397.jpg
#   inflating: cite_images/100060321.jpg
#   inflating: cite_images/100031608.jpg
#   inflating: cite_images/100029047.jpg
#   inflating: cite_images/100066988.jpg
#   inflating: cite_images/100070132.jpg
#   inflating: cite_images/100036167.jpg
#   inflating: cite_images/100019184.jpg
#   inflating: cite_images/100039254.jpg
#   inflating: cite_images/100103876.jpg
#   inflating: cite_images/100095800.jpg
#   inflating: cite_images/100069463.jpg
#   inflating: cite_images/100037279.jpg
#   inflating: cite_images/100046480.jpg
#   inflating: cite_images/100020705.jpg
#   inflating: cite_images/100066750.jpg
#   inflating: cite_images/100058866.jpg
#   inflating: cite_images/100077885.jpg
#   inflating: cite_images/100001913.jpg
#   inflating: cite_images/100047946.jpg
#   inflating: cite_images/100079670.jpg
#   inflating: cite_images/100008089.jpg
#   inflating: cite_images/100056693.jpg
#   inflating: cite_images/100028359.jpg
#   inflating: cite_images/100076543.jpg
#   inflating: cite_images/100030516.jpg
#   inflating: cite_images/100053933.jpg
#   inflating: cite_images/100015966.jpg
#   inflating: cite_images/100024563.jpg
#   inflating: cite_images/100090978.jpg
#   inflating: cite_images/100062536.jpg
#   inflating: cite_images/100065259.jpg
#   inflating: cite_images/100072725.jpg
#   inflating: cite_images/100045189.jpg
#   inflating: cite_images/100034770.jpg
#   inflating: cite_images/100022112.jpg
#   inflating: cite_images/100064147.jpg
#   inflating: cite_images/100044297.jpg
#   inflating: cite_images/100081875.jpg
#   inflating: cite_images/100108923.jpg
#   inflating: cite_images/100074354.jpg
#   inflating: cite_images/100032301.jpg
#   inflating: cite_images/100063628.jpg
#   inflating: cite_images/100054084.jpg
#   inflating: cite_images/100074432.jpg
#   inflating: cite_images/100032467.jpg
#   inflating: cite_images/100003862.jpg
#   inflating: cite_images/100045837.jpg
#   inflating: cite_images/100022674.jpg
#   inflating: cite_images/100109383.jpg
#   inflating: cite_images/100064621.jpg
#   inflating: cite_images/100035308.jpg
#   inflating: cite_images/100088689.jpg
#   inflating: cite_images/100101907.jpg
#   inflating: cite_images/100097971.jpg
#   inflating: cite_images/100052393.jpg
#   inflating: cite_images/100072043.jpg
#   inflating: cite_images/100089597.jpg
#   inflating: cite_images/100034016.jpg
#   inflating: cite_images/100042180.jpg
#   inflating: cite_images/100033779.jpg
#   inflating: cite_images/100024205.jpg
#   inflating: cite_images/100099784.jpg
#   inflating: cite_images/100088851.jpg
#   inflating: cite_images/100062250.jpg
#   inflating: cite_images/100061759.jpg
#   inflating: cite_images/100079116.jpg
#   inflating: cite_images/100076225.jpg
#   inflating: cite_images/100030270.jpg
#   inflating: cite_images/100041489.jpg
#   inflating: cite_images/100069305.jpg
#   inflating: cite_images/100083904.jpg
#   inflating: cite_images/100020063.jpg
#   inflating: cite_images/100066036.jpg
#   inflating: cite_images/100070654.jpg
#   inflating: cite_images/100061981.jpg
#   inflating: cite_images/100036601.jpg
#   inflating: cite_images/100008937.jpg
#   inflating: cite_images/100067328.jpg
#   inflating: cite_images/100039532.jpg
#   inflating: cite_images/100050584.jpg
#   inflating: cite_images/100026412.jpg
#   inflating: cite_images/100092809.jpg
#   inflating: cite_images/100078208.jpg
#   inflating: cite_images/100060447.jpg
#   inflating: cite_images/100051842.jpg
#   inflating: cite_images/100040797.jpg
#   inflating: cite_images/100017817.jpg
#   inflating: cite_images/100029721.jpg
#   inflating: cite_images/100027718.jpg
#   inflating: cite_images/100079102.jpg
#   inflating: cite_images/100070898.jpg
#   inflating: cite_images/100030264.jpg
#   inflating: cite_images/100076231.jpg
#   inflating: cite_images/100083910.jpg
#   inflating: cite_images/100069311.jpg
#   inflating: cite_images/100066022.jpg
#   inflating: cite_images/100038638.jpg
#   inflating: cite_images/100020077.jpg
#   inflating: cite_images/100008923.jpg
#   inflating: cite_images/100036615.jpg
#   inflating: cite_images/100061995.jpg
#   inflating: cite_images/100070640.jpg
#   inflating: cite_images/100050590.jpg
#   inflating: cite_images/100021369.jpg
#   inflating: cite_images/100039526.jpg
#   inflating: cite_images/100060453.jpg
#   inflating: cite_images/100026406.jpg
#   inflating: cite_images/100029735.jpg
#   inflating: cite_images/100017803.jpg
#   inflating: cite_images/100040783.jpg
#   inflating: cite_images/100051856.jpg
#   inflating: cite_images/100086868.jpg
#   inflating: cite_images/100032473.jpg
#   inflating: cite_images/100074426.jpg
#   inflating: cite_images/100045823.jpg
#   inflating: cite_images/100003876.jpg
#   inflating: cite_images/100064635.jpg
#   inflating: cite_images/100109397.jpg
#   inflating: cite_images/100022660.jpg
#   inflating: cite_images/100053099.jpg
#   inflating: cite_images/100099948.jpg
#   inflating: cite_images/100073349.jpg
#   inflating: cite_images/100052387.jpg
#   inflating: cite_images/100097965.jpg
#   inflating: cite_images/100101913.jpg
#   inflating: cite_images/100108089.jpg
#   inflating: cite_images/100034002.jpg
#   inflating: cite_images/100089583.jpg
#   inflating: cite_images/100072057.jpg
#   inflating: cite_images/100075738.jpg
#   inflating: cite_images/100042194.jpg
#   inflating: cite_images/100062244.jpg
#   inflating: cite_images/100088845.jpg
#   inflating: cite_images/100099790.jpg
#   inflating: cite_images/100024211.jpg
#   inflating: cite_images/100015972.jpg
#   inflating: cite_images/100053927.jpg
#   inflating: cite_images/100062522.jpg
#   inflating: cite_images/100024577.jpg
#   inflating: cite_images/100023218.jpg
#   inflating: cite_images/100034764.jpg
#   inflating: cite_images/100072731.jpg
#   inflating: cite_images/100064153.jpg
#   inflating: cite_images/100022106.jpg
#   inflating: cite_images/100081861.jpg
#   inflating: cite_images/100044283.jpg
#   inflating: cite_images/100032315.jpg
#   inflating: cite_images/100074340.jpg
#   inflating: cite_images/100108937.jpg
#   inflating: cite_images/100025669.jpg
#   inflating: cite_images/100054090.jpg
#   inflating: cite_images/100060335.jpg
#   inflating: cite_images/100009383.jpg
#   inflating: cite_images/100057599.jpg
#   inflating: cite_images/100026360.jpg
#   inflating: cite_images/100029053.jpg
#   inflating: cite_images/100077649.jpg
#   inflating: cite_images/100019190.jpg
#   inflating: cite_images/100068769.jpg
#   inflating: cite_images/100036173.jpg
#   inflating: cite_images/100070126.jpg
#   inflating: cite_images/100095814.jpg
#   inflating: cite_images/100103862.jpg
#   inflating: cite_images/100039240.jpg
#   inflating: cite_images/100071238.jpg
#   inflating: cite_images/100046494.jpg
#   inflating: cite_images/100069477.jpg
#   inflating: cite_images/100077891.jpg
#   inflating: cite_images/100058872.jpg
#   inflating: cite_images/100066744.jpg
#   inflating: cite_images/100020711.jpg
#   inflating: cite_images/100056687.jpg
#   inflating: cite_images/100079664.jpg
#   inflating: cite_images/100047952.jpg
#   inflating: cite_images/100001907.jpg
#   inflating: cite_images/100084919.jpg
#   inflating: cite_images/100030502.jpg
#   inflating: cite_images/100076557.jpg

# %% [markdown]
# ## Load data

# %%
def make_train_label(train_df) -> pd.DataFrame:
    le = LabelEncoder()
    train_df["brand_id_label"] = le.fit_transform(train_df["brand_id"])
    train_df["meigara_label"] = le.fit_transform(train_df["meigara"])

    return train_df


def make_filepath(input_df):
    def join_path(dirpath, filename):
        return (dirpath / filename).as_posix()

    output_df = input_df.assign(
        filepath=input_df["filename"].apply(
            lambda x: join_path(QUERY_IMAGES, x) if str(x)[0] == "2" else join_path(CITE_IMAGES, x)
        )
    )
    return output_df

def make_label_dict(train_df):
    MLABEL2MEIGARA = train_df[["meigara", "meigara_label"]].set_index("meigara_label").to_dict()["meigara"]
    BLABEL2BLAND = train_df[["brand_id", "brand_id_label"]].set_index("brand_id_label").to_dict()["brand_id"]
    return MLABEL2MEIGARA, BLABEL2BLAND

# %%
# load raw data
train_df = pd.read_csv(INPUTS / "train.csv")
test_df = pd.read_csv(INPUTS / "test.csv")
cite_df = pd.read_csv(INPUTS / "cite.csv").rename(columns={"cite_gid":"gid", "cite_filename":"filename"})
sample_submission_df = pd.read_csv(INPUTS / "sample_submission.csv")

if Config.debug:
    train_df = train_df.sample(1000, random_state=Config.seed).reset_index(drop=True)
    cite_df = cite_df.sample(100, random_state=Config.seed).reset_index(drop=True)

# make label
train_df = make_train_label(train_df)
MLABEL2MEIGARA, BLABEL2BLAND = make_label_dict(train_df)
Config.num_classes = len(MLABEL2MEIGARA)

# make filepath
train_df = make_filepath(train_df)
test_df = make_filepath(test_df)
cite_df = make_filepath(cite_df)

# for submission
IDX2CITE_GID = cite_df.to_dict()["gid"]

print(train_df.shape)
# Out:
# (108160, 7)

# %% [markdown]
# ## CV Split

# %%
def add_fold_idx(config, train_df):
    fold = StratifiedKFold(n_splits=config.n_fold, shuffle=True, random_state=config.seed)
    train_df["fold"] = -1
    for i_fold, (train_index, val_index) in enumerate(
        fold.split(train_df, train_df[config.target_columns])
    ):
        train_df.iloc[val_index, train_df.columns.get_loc("fold")] = int(i_fold)
    train_df["fold"] = train_df["fold"].astype(int)
    return train_df

# %%
train_df = add_fold_idx(config=Config, train_df=train_df)
train_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
#          gid       filename  brand_id meigara  brand_id_label  meigara_label  \
# 0  200000001  200000001.jpg      3372      五橋            2211            445
# 1  200000002  200000002.jpg      3751  庭のうぐいす            2454           1122
# 2  200000003  200000003.jpg      2856     笑四季            1864           1819
# 3  200000004  200000004.jpg      1527      鍋島            1005           2263
# 4  200000005  200000005.jpg      2676      仙禽            1739            478
#
#                      filepath  fold
# 0  query_images/200000001.jpg     2
# 1  query_images/200000002.jpg     2
# 2  query_images/200000003.jpg     1
# 3  query_images/200000004.jpg     0
# 4  query_images/200000005.jpg     1

# %% [markdown]
# ## Dataset

# %%
class TrainDataset(Dataset):
    def __init__(self,df, target_columns=Config.target_columns, transform_fn=None):
        self.df = df
        self.file_names = df["filepath"].to_numpy()
        self.targets = df[target_columns].to_numpy()
        if len(target_columns) == 1:
            self.targets = np.ravel(self.targets)

        self.transform_fn = transform_fn

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        filepath = self.file_names[idx]
        image = cv2.imread(filepath)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform_fn:
            image = self.transform_fn(image=image)["image"]
        target = torch.tensor(self.targets[idx])
        return {"images":image, "targets":target}


class TestDataset(Dataset):
    def __init__(self, df, transform_fn=None):
        self.df = df
        self.file_names = df["filepath"].to_numpy()
        self.transform_fn = transform_fn

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        filepath = self.file_names[idx]
        image = cv2.imread(filepath)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform_fn:
            image = self.transform_fn(image=image)["image"]
        return {"images":image}

# %% [markdown]
# ## Transforms

# %%
def set_transform(dataset, transform):
    if isinstance(dataset, torch.utils.data.Subset):
        set_transform(dataset.dataset, transform)
    else:
        dataset.transform_fn = transform


def get_transforms(size, data="train", p=0.5):

    if data == 'train':
        return A.Compose([
            # 正方形切り出し
            A.RandomResizedCrop(size, size, scale=(0.85, 1.0)),
            A.OneOf(
                transforms=[
                    A.augmentations.geometric.rotate.SafeRotate(
                        limit=(-45, -90),
                    ),
                    A.augmentations.geometric.rotate.SafeRotate(
                        limit=(45, 90),
                    )
                ],
                p=p
            ),
            A.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

    elif data == 'valid':
        return A.Compose([
            A.Resize(size, size),
            A.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

# %%
train_dataset = TrainDataset(df=train_df, transform_fn=get_transforms(data="train", size=Config.size, p=0))
japanize_matplotlib.japanize()
train_dataloader = DataLoader(
    train_dataset,
    batch_size=Config.train_batch_size,
    shuffle=False,
    num_workers=Config.num_workers,
    pin_memory=True,
    drop_last=True,
)
set_transform(train_dataset, get_transforms(data='train', size=Config.size, p=1))
for batch in train_dataloader:
    break
image, label = batch["images"].numpy().transpose(0, 2, 3, 1),  batch["targets"].numpy()
for i in range(5):
    plt.figure(figsize=(4, 4))
    plt.imshow(image[i])
    plt.title(f"label: {int(label[i])} {MLABEL2MEIGARA[int(label[i])]}")
    plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Model

# %%
class CustomModel(nn.Module):
    def __init__(self, config, pretrained=False):
        super().__init__()
        self.config = config
        self.model = timm.create_model(
            self.config.model_name,
            pretrained=pretrained,
            features_only=True
        )
        self.n_features = self.model.feature_info[-1]['num_chs']
        self.global_pool = GeM()
        self.fc = nn.Linear(self.n_features, config.embedding_dim)
        self.out = ElasticCosFace(
            config.embedding_dim,
            config.num_classes,
            plus=config.use_plus,
            s=config.s,
            m=config.m
        )

    def forward(self, x, label):
        x = self.extract_features(x)
        x = self.out(x, label)
        return x

    def extract_features(self, images, labels=None):
        bs = images.size(0)
        x = self.model(images)[-1]
        x = self.global_pool(x).view(bs, -1)
        x = self.fc(x)
        return x

# %%
model = CustomModel(Config, pretrained=True).cuda()
outputs = model(torch.rand(2, 3, Config.size, Config.size).cuda(), torch.tensor([1, 1]).cuda())
outputs.size()
# Out:
# torch.Size([2, 464])

# %% [markdown]
# ## Funcs

# %%
def train_fn(
    config,
    model,
    dataloader,
    criterion,
    optimizer,
    scheduler,
    _custom_step,
):
    model.train()
    scaler = torch.cuda.amp.GradScaler(init_scale=256, enabled=config.use_amp)
    losses = []

    tbar = tqdm(enumerate(dataloader), total=len(dataloader))
    for step, batch in tbar:
        for k, v in batch.items():
            batch[k] = v.to(config.device)
        targets = batch["targets"]
        batch_size = targets.size(0)

        with torch.cuda.amp.autocast(enabled=config.use_amp):
            batch_outputs = model(batch["images"], label=batch["targets"])
            loss = criterion(batch_outputs, targets)

        if config.gradient_accumulation_steps > 1:
            loss = loss / config.gradient_accumulation_steps

        scaler.scale(loss).backward()
        if config.clip_grad_norm is not None:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), config.clip_grad_norm)
            torch.nn.utils.clip_grad_norm_(criterion.parameters(), config.clip_grad_norm)

        if (step + 1) % config.gradient_accumulation_steps == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()
            _custom_step += 1
            if config.batch_scheduler:
                scheduler.step()

        losses.append(float(loss) * config.gradient_accumulation_steps)
        tbar.set_description(f"loss: {np.mean(losses) :.4f} lr: {scheduler.get_lr()[0]:.6f}")

    loss = np.mean(losses)
    return loss, _custom_step


def extract_features(model, data_loader, device):
    preds, targets = [], []
    model.eval()
    tbar = tqdm(data_loader, total=len(data_loader))
    for batch in tbar:
        for k, v in batch.items():
            batch[k] = v.to(device)
        with torch.no_grad():
            outputs = model.extract_features(batch['images'])
        outputs = outputs.cpu().detach().numpy()
        target_labels = batch['targets'].cpu().detach().numpy()
        preds.append(outputs)
        targets.append(target_labels)
    return np.concatenate(preds), np.concatenate(targets)

# %%
def get_optimizer(optimizer_config, params):
    if optimizer_config["optimizer_name"] == "AdamW":
        optimizer = AdamW(
            params,
            lr=optimizer_config["lr"],
            betas=optimizer_config["beta"],
            eps=optimizer_config["eps"],
        )
        return optimizer
    else:
        raise NotImplementedError


def get_scheduler(scheduler_config, optimizer, num_train_steps):
    if scheduler_config["scheduler_name"] == "linear":
        scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=int(scheduler_config["num_warmup_steps_rate"] * num_train_steps),
            num_training_steps=num_train_steps,
        )
        return scheduler

    elif scheduler_config["scheduler_name"] == "cosine":
        scheduler = get_cosine_schedule_with_warmup(
            optimizer,
            num_warmup_steps=int(scheduler_config["num_warmup_steps_rate"] * num_train_steps),
            num_training_steps=num_train_steps,
            num_cycles=scheduler_config["num_cycles"],
        )
        return scheduler

    elif scheduler_config["scheduler_name"] == "cosine_restarts":
        """
        example:
            first_cycle_steps_ratio = 0.25,
            cycle_mult = 1.0,
            max_lr = 2e-5,
            min_lr = 1e-7,
            warmup_steps=100,
            gamma=0.8)
        """
        scheduler = CosineAnnealingWarmupRestarts(
            optimizer,
            first_cycle_steps=int(num_train_steps * scheduler_config["first_cycle_steps_ratio"]),
            cycle_mult=scheduler_config["cycle_mult"],
            max_lr=scheduler_config["max_lr"],
            min_lr=scheduler_config["min_lr"],
            warmup_steps=scheduler_config["warmup_steps"],
            gamma=scheduler_config["gamma"],
        )
        return scheduler

    else:
        raise NotImplementedError

# %%
def get_probability_by_epoch(epoch: int):
    return 2 ** (- epoch)


def train_loop(config, name, train_df, index_df, query_df, criterion):
    LOGGER.info(f"========== {name} training ==========")

    # dataloader
    train_dataloader, index_dataloader, query_dataloader = get_dl(
        train_df,
        index_df,
        query_df,
        config,
        epoch=1
    )

    # set model & optimizer
    model = CustomModel(config, pretrained=True)
    model.to(config.device)
    criterion.to(config.device)
    params = [
        {'params': model.parameters()},
        {'params': criterion.parameters()}
    ]
    optimizer = get_optimizer(optimizer_config=config.optimizer, params=params)

    # set scheduler
    num_train_steps = int(
        len(train_dataloader) * config.max_epochs // config.gradient_accumulation_steps
    )
    scheduler = get_scheduler(
        scheduler_config=config.scheduler, optimizer=optimizer, num_train_steps=num_train_steps
    )

    # loop
    best_mrr = -np.inf
    tr_step, val_step = 0, 0
    for epoch in range(Config.max_epochs):
        train_dataloader, index_dataloader, query_dataloader = get_dl(
            train_df,
            index_df,
            query_df,
            config,
            epoch+1
        )
        LOGGER.info(train_dataloader.dataset.transform_fn)
        # training
        loss, tr_step = train_fn(
            config=config,
            model=model,
            dataloader=train_dataloader,
            criterion=criterion,
            optimizer=optimizer,
            scheduler=scheduler,
            _custom_step=tr_step,
        )
        torch.cuda.empty_cache()
        gc.collect()

        # validation
        index_preds, index_targets = extract_features(model, index_dataloader, config.device)
        query_preds, query_targets = extract_features(model, query_dataloader, config.device)
        searcher = SimilaritySearcher(index_preds)
        _, I = searcher.search(query_preds)
        mrr = mrr_at_k_by_searched_index(query_targets, index_targets, I)

        logs = {
            "Epoch": epoch,
            "train_loss_epoch": loss.item(),
            "valid_mrr": mrr,
        }
        LOGGER.info(logs)

        if mrr > best_mrr:
            best_mrr = mrr
            LOGGER.info(f"epoch {epoch} - best mrr: {best_mrr:.4f} model")

            torch.save(model.state_dict(), f"{name}.pth")  # save model weight

        if not config.batch_scheduler:
            scheduler.step()

    torch.cuda.empty_cache()
    gc.collect()

    # to escape drive storage error
    copy_file(f"{name}.pth", EXP_MODELS / f"{name}.pth")

    return best_mrr

def get_dl(train_df, index_df, query_df, config=Config, epoch=1):
    assert epoch != 0
    train_dataset = TrainDataset(
        df=train_df,
        target_columns=config.target_columns,
        transform_fn=get_transforms(data="train", size=config.size, p=get_probability_by_epoch(epoch))
    )
    index_dataset = TrainDataset(
        df=index_df,
        target_columns=config.target_columns,
        transform_fn=get_transforms(data="valid", size=config.size)
    )
    query_dataset = TrainDataset(
        df=query_df,
        target_columns=config.target_columns,
        transform_fn=get_transforms(data="valid", size=config.size)
    )
    train_dataloader = DataLoader(
        train_dataset,
        batch_size=config.train_batch_size,
        shuffle=True,
        num_workers=config.num_workers,
        pin_memory=True,
        drop_last=True,
    )
    index_dataloader = DataLoader(
        index_dataset,
        batch_size=config.valid_batch_size,
        num_workers=config.num_workers,
        pin_memory=True,
        drop_last=False,
    )
    query_dataloader = DataLoader(
        query_dataset,
        batch_size=config.valid_batch_size,
        num_workers=config.num_workers,
        pin_memory=True,
        drop_last=False,
    )
    return train_dataloader, index_dataloader, query_dataloader


def get_index_and_query_df(base_df, target_col=Config.target_columns[0], unique_id_col='gid', seed=Config.seed):
    """index, queryに対応するデータフレームを返す
    Args:
        base_df: 分岐元データフレーム
        target_col: 目的変数絡む
        unique_id_col: ユニークなカラム名
        seed: queryを選択する際のシード値
    Returns:
        (indexデータフレーム, queryデータフレーム)
    """
    # カウント数が1より多いものをクエリー画像候補とする。
    counts_df = base_df[target_col].value_counts()
    counts_df = counts_df[counts_df != 1]
    query_candidates = base_df[base_df[target_col].isin(counts_df.index)]
    # 目的変数から各カテゴリ1つずつランダムに取得してクエリ画像とする。
    query_target_target_id_list = query_candidates.groupby(target_col).sample(
        1,
        random_state=seed)[unique_id_col].to_list()
    is_query_filter = base_df[unique_id_col].isin(query_target_target_id_list)
    return base_df[~is_query_filter], base_df[is_query_filter]

# %% [markdown]
# ## Training
# - multi class calssification

# %%
seed_torch()
mrr_list = []
if Config.training:
    for i_fold in range(Config.n_fold):
        if i_fold not in Config.trn_fold:
            print(f'fold {i_fold} skipped')
            continue

        train_df_fold = train_df[train_df["fold"] != i_fold]
        valid_df_fold = train_df[train_df["fold"] == i_fold]
        index_df, query_df = get_index_and_query_df(valid_df_fold)
        criterion = nn.CrossEntropyLoss()

        summary_writer = SummaryWriter(log_dir=OUTPUTS_EXP / f'fold_{i_fold}')
        mrr_score = train_loop(
            config=Config,
            name=f"fold_{i_fold}",
            train_df=train_df_fold,
            index_df=index_df,
            query_df=query_df,
            criterion=criterion
        )
        mrr_list.append(mrr_score)
LOGGER.info(mrr_list)
# Out:
# [2023-09-10 05:32:01] - ========== fold_2 training ==========
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 05:32:01] - ========== fold_2 training ==========
# fold 0 skipped
# fold 1 skipped
# [2023-09-10 05:32:08] - Compose([
#   RandomResizedCrop(always_apply=False, p=1.0, height=448, width=448, scale=(0.85, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1),
#   OneOf([
#     SafeRotate(always_apply=False, p=0.5, limit=(-45, -90), interpolation=1, border_mode=4, value=None, mask_value=None),
#     SafeRotate(always_apply=False, p=0.5, limit=(45, 90), interpolation=1, border_mode=4, value=None, mask_value=None),
#   ], p=0.5),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 05:32:08] - Compose([
#   RandomResizedCrop(always_apply=False, p=1.0, height=448, width=448, scale=(0.85, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1),
#   OneOf([
#     SafeRotate(always_apply=False, p=0.5, limit=(-45, -90), interpolation=1, border_mode=4, value=None, mask_value=None),
#     SafeRotate(always_apply=False, p=0.5, limit=(45, 90), interpolation=1, border_mode=4, value=None, mask_value=None),
#   ], p=0.5),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
#   0%|          | 0/9013 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:265: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# loss: 8.8002 lr: 0.000097: 100%|██████████| 9013/9013 [56:52<00:00,  2.64it/s]
# 100%|██████████| 629/629 [16:26<00:00,  1.57s/it]
# 100%|██████████| 27/27 [00:43<00:00,  1.63s/it]
# [mrr]: 100%|██████████| 1485/1485 [00:00<00:00, 232113.79it/s]
# [2023-09-10 06:46:12] - {'Epoch': 0, 'train_loss_epoch': 8.800176282592583, 'valid_mrr': 0.6612642285937936}
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 06:46:12] - {'Epoch': 0, 'train_loss_epoch': 8.800176282592583, 'valid_mrr': 0.6612642285937936}
# [2023-09-10 06:46:12] - epoch 0 - best mrr: 0.6613 model
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 06:46:12] - epoch 0 - best mrr: 0.6613 model
# [2023-09-10 06:46:13] - Compose([
#   RandomResizedCrop(always_apply=False, p=1.0, height=448, width=448, scale=(0.85, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1),
#   OneOf([
#     SafeRotate(always_apply=False, p=0.5, limit=(-45, -90), interpolation=1, border_mode=4, value=None, mask_value=None),
#     SafeRotate(always_apply=False, p=0.5, limit=(45, 90), interpolation=1, border_mode=4, value=None, mask_value=None),
#   ], p=0.25),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 06:46:13] - Compose([
#   RandomResizedCrop(always_apply=False, p=1.0, height=448, width=448, scale=(0.85, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1),
#   OneOf([
#     SafeRotate(always_apply=False, p=0.5, limit=(-45, -90), interpolation=1, border_mode=4, value=None, mask_value=None),
#     SafeRotate(always_apply=False, p=0.5, limit=(45, 90), interpolation=1, border_mode=4, value=None, mask_value=None),
#   ], p=0.25),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
#   0%|          | 0/9013 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:265: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# loss: 4.0846 lr: 0.000075: 100%|██████████| 9013/9013 [56:56<00:00,  2.64it/s]
# 100%|██████████| 629/629 [16:25<00:00,  1.57s/it]
# 100%|██████████| 27/27 [00:43<00:00,  1.62s/it]
# [mrr]: 100%|██████████| 1485/1485 [00:00<00:00, 396419.39it/s]
# [2023-09-10 08:00:21] - {'Epoch': 1, 'train_loss_epoch': 4.084626133936525, 'valid_mrr': 0.7028900285333036}
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 08:00:21] - {'Epoch': 1, 'train_loss_epoch': 4.084626133936525, 'valid_mrr': 0.7028900285333036}
# [2023-09-10 08:00:21] - epoch 1 - best mrr: 0.7029 model
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 08:00:21] - epoch 1 - best mrr: 0.7029 model
# [2023-09-10 08:00:22] - Compose([
#   RandomResizedCrop(always_apply=False, p=1.0, height=448, width=448, scale=(0.85, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1),
#   OneOf([
#     SafeRotate(always_apply=False, p=0.5, limit=(-45, -90), interpolation=1, border_mode=4, value=None, mask_value=None),
#     SafeRotate(always_apply=False, p=0.5, limit=(45, 90), interpolation=1, border_mode=4, value=None, mask_value=None),
#   ], p=0.125),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 08:00:22] - Compose([
#   RandomResizedCrop(always_apply=False, p=1.0, height=448, width=448, scale=(0.85, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1),
#   OneOf([
#     SafeRotate(always_apply=False, p=0.5, limit=(-45, -90), interpolation=1, border_mode=4, value=None, mask_value=None),
#     SafeRotate(always_apply=False, p=0.5, limit=(45, 90), interpolation=1, border_mode=4, value=None, mask_value=None),
#   ], p=0.125),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
#   0%|          | 0/9013 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:265: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# loss: 2.3995 lr: 0.000041: 100%|██████████| 9013/9013 [56:55<00:00,  2.64it/s]
# 100%|██████████| 629/629 [16:26<00:00,  1.57s/it]
# 100%|██████████| 27/27 [00:43<00:00,  1.62s/it]
# [mrr]: 100%|██████████| 1485/1485 [00:00<00:00, 305635.28it/s]
# [2023-09-10 09:14:29] - {'Epoch': 2, 'train_loss_epoch': 2.3994835291376497, 'valid_mrr': 0.7291277289759014}
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 09:14:29] - {'Epoch': 2, 'train_loss_epoch': 2.3994835291376497, 'valid_mrr': 0.7291277289759014}
# [2023-09-10 09:14:29] - epoch 2 - best mrr: 0.7291 model
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 09:14:29] - epoch 2 - best mrr: 0.7291 model
# [2023-09-10 09:14:32] - Compose([
#   RandomResizedCrop(always_apply=False, p=1.0, height=448, width=448, scale=(0.85, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1),
#   OneOf([
#     SafeRotate(always_apply=False, p=0.5, limit=(-45, -90), interpolation=1, border_mode=4, value=None, mask_value=None),
#     SafeRotate(always_apply=False, p=0.5, limit=(45, 90), interpolation=1, border_mode=4, value=None, mask_value=None),
#   ], p=0.0625),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 09:14:32] - Compose([
#   RandomResizedCrop(always_apply=False, p=1.0, height=448, width=448, scale=(0.85, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1),
#   OneOf([
#     SafeRotate(always_apply=False, p=0.5, limit=(-45, -90), interpolation=1, border_mode=4, value=None, mask_value=None),
#     SafeRotate(always_apply=False, p=0.5, limit=(45, 90), interpolation=1, border_mode=4, value=None, mask_value=None),
#   ], p=0.0625),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
#   0%|          | 0/9013 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:265: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# loss: 1.2897 lr: 0.000012: 100%|██████████| 9013/9013 [56:52<00:00,  2.64it/s]
# 100%|██████████| 629/629 [16:26<00:00,  1.57s/it]
# 100%|██████████| 27/27 [00:43<00:00,  1.62s/it]
# [mrr]: 100%|██████████| 1485/1485 [00:00<00:00, 326854.61it/s]
# [2023-09-10 10:28:36] - {'Epoch': 3, 'train_loss_epoch': 1.289717168115186, 'valid_mrr': 0.7502840230136414}
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 10:28:36] - {'Epoch': 3, 'train_loss_epoch': 1.289717168115186, 'valid_mrr': 0.7502840230136414}
# [2023-09-10 10:28:36] - epoch 3 - best mrr: 0.7503 model
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 10:28:36] - epoch 3 - best mrr: 0.7503 model
# [2023-09-10 10:28:38] - Compose([
#   RandomResizedCrop(always_apply=False, p=1.0, height=448, width=448, scale=(0.85, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1),
#   OneOf([
#     SafeRotate(always_apply=False, p=0.5, limit=(-45, -90), interpolation=1, border_mode=4, value=None, mask_value=None),
#     SafeRotate(always_apply=False, p=0.5, limit=(45, 90), interpolation=1, border_mode=4, value=None, mask_value=None),
#   ], p=0.03125),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 10:28:38] - Compose([
#   RandomResizedCrop(always_apply=False, p=1.0, height=448, width=448, scale=(0.85, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1),
#   OneOf([
#     SafeRotate(always_apply=False, p=0.5, limit=(-45, -90), interpolation=1, border_mode=4, value=None, mask_value=None),
#     SafeRotate(always_apply=False, p=0.5, limit=(45, 90), interpolation=1, border_mode=4, value=None, mask_value=None),
#   ], p=0.03125),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
#   0%|          | 0/9013 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:265: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# loss: 0.6950 lr: 0.000000: 100%|██████████| 9013/9013 [56:54<00:00,  2.64it/s]
# 100%|██████████| 629/629 [16:26<00:00,  1.57s/it]
# 100%|██████████| 27/27 [00:43<00:00,  1.62s/it]
# [mrr]: 100%|██████████| 1485/1485 [00:00<00:00, 318188.58it/s]
# [2023-09-10 11:42:44] - {'Epoch': 4, 'train_loss_epoch': 0.695039174679539, 'valid_mrr': 0.754946443655594}
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 11:42:44] - {'Epoch': 4, 'train_loss_epoch': 0.695039174679539, 'valid_mrr': 0.754946443655594}
# [2023-09-10 11:42:44] - epoch 4 - best mrr: 0.7549 model
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 11:42:44] - epoch 4 - best mrr: 0.7549 model
# [2023-09-10 11:42:48] - [0.754946443655594]
# INFO:/content/drive/MyDrive/competition/nishika_sake/outputs/convnextv2:[2023-09-10 11:42:48] - [0.754946443655594]
# copy complete

# %% [markdown]
# ## Embeddings

# %%
def inference_fn(test_dataloader, model, device, features=False):
    preds, targets_masks = [], []
    model.eval()
    model.to(device)

    tbar = tqdm(test_dataloader, total=len(test_dataloader))
    for batch in tbar:
        for k, v in batch.items():
            batch[k] = v.to(device)

        with torch.no_grad():
            outputs = model.extract_features(batch["images"])

        outputs = outputs.cpu().detach().numpy()
        preds.append(outputs)

    return np.concatenate(preds)


def get_features(config, test_df, model_path):
    test_dataset = TestDataset(df=test_df, transform_fn=get_transforms(data="valid", size=config.size))
    test_dataloader = DataLoader(
        test_dataset,
        batch_size=config.valid_batch_size,
        shuffle=False,
        num_workers=config.num_workers,
        pin_memory=True,
        drop_last=False,
    )

    # get model
    model = CustomModel(config, pretrained=False)
    state = torch.load(model_path)
    model.load_state_dict(state)
    features = inference_fn(test_dataloader, model, config.device, features=True)

    del model, state, test_dataloader
    gc.collect()
    torch.cuda.empty_cache()

    outputs = {
        "gid": test_df["gid"].tolist(),
        "features": np.array(features, dtype=np.float16),
    }
    return outputs

# %%
if Config.embedding:
    # oof
    # oof_features_filepath = EXP_PREDS / "oof_embeddings.pkl"
    # if not oof_features_filepath.is_file():
    #     oof_features, oof_gids = [], []
    #     for i_fold in range(Config.n_fold):
    #         if i_fold not in Config.trn_fold:
    #             continue

    #         gids = joblib.load(EXP_PREDS / f"fold_{i_fold}_best.pkl")["gid"]
    #         df = train_df[train_df["gid"].isin(gids)].reset_index(drop=True)

    #         outputs = get_features(
    #             config=Config,
    #             test_df=df,
    #             model_path=EXP_MODELS / f"fold_{i_fold}.pth",
    #             device=DEVICE
    #             )
    #         oof_features.append(outputs["features"])
    #         oof_gids.extend(outputs["gid"])
    #     oof_features = np.concatenate(oof_features, axis=0)
    #     joblib.dump({"gid":oof_gids, "embeddings":oof_features}, oof_features_filepath)

    # query images
    query_features_filepath = EXP_PREDS / "test_embeddings.pkl"
    if not query_features_filepath.is_file():
        query_features = []
        for i_fold in range(Config.n_fold):
            if i_fold not in Config.trn_fold:
                continue

            outputs = get_features(
                config=Config,
                test_df=test_df,
                model_path=EXP_MODELS / f"fold_{i_fold}.pth",
            )
            query_features.append(outputs["features"])
        joblib.dump({"gid":outputs["gid"], "embeddings_list":query_features}, query_features_filepath)

    # cite images
    cite_features_filepath = EXP_PREDS / "cite_embeddings.pkl"
    if not cite_features_filepath.is_file():
        cite_features = []
        for i_fold in range(Config.n_fold):
            if i_fold not in Config.trn_fold:
                continue

            outputs = get_features(
                config=Config,
                test_df=cite_df,
                model_path=EXP_MODELS / f"fold_{i_fold}.pth",
            )
            cite_features.append(outputs["features"])
        joblib.dump({"gid":outputs["gid"], "embeddings_list":cite_features}, cite_features_filepath)
# Out:
# 100%|██████████| 1991/1991 [52:09<00:00,  1.57s/it]
# 100%|██████████| 1991/1991 [52:02<00:00,  1.57s/it]
# 100%|██████████| 1991/1991 [52:00<00:00,  1.57s/it]

# %% [markdown]
# ## Similarity

# %%
class SimilaritySearcher:
    def __init__(self, embeddings):
        self.dimension = embeddings.shape[1]
        self.index = faiss.IndexFlatL2(self.dimension)
        faiss.normalize_L2(embeddings)
        self.index.add(embeddings)  # type:ignore

    def search(self, queries, k=10):
        assert queries.shape[1] == self.dimension, "Query dimensions should match embeddings dimension."
        faiss.normalize_L2(queries)
        D, I = self.index.search(queries, k)  # type:ignore
        return D, I

# %%
cite_features = np.array(joblib.load(EXP_PREDS / "cite_embeddings.pkl")["embeddings_list"])
query_features = np.array(joblib.load(EXP_PREDS / "test_embeddings.pkl")["embeddings_list"])

ave_cite_feature = np.mean(cite_features, axis=0)
ave_query_feature = np.mean(query_features, axis=0)

searcher = SimilaritySearcher(ave_cite_feature.astype(np.float32))
D, I = searcher.search(ave_query_feature.astype(np.float32), k=20)

# %% [markdown]
# ## Make submission

# %%
def make_submission(indices):
    vfunc = np.vectorize(lambda x: IDX2CITE_GID[x])
    gid_array = vfunc(I)
    submission_df = test_df[["gid"]].assign(cite_gid=[" ".join(list(x)) for x in gid_array.astype(str)])
    return submission_df

# %%
submission_df = make_submission(indices=I)
submission_df.to_csv(SUBMISSIONS / f"{Config.name}.csv", index=False)

# %% [markdown]
# ## Result

# %%
submission_df = pd.read_csv(SUBMISSIONS / f"{Config.name}.csv")

# %%
import cv2
import matplotlib.pyplot as plt

def display_similar_images(query_path, cite_paths):
    num_similar = len(cite_paths)

    # Query画像の読み込み
    query_image = cv2.imread(query_path)
    query_image = cv2.cvtColor(query_image, cv2.COLOR_BGR2RGB)

    # 類似画像の読み込みと表示
    num_rows = (num_similar + 1) // 2
    fig, axs = plt.subplots(num_rows, 2, figsize=(10, 10), squeeze=False)

    axs[0, 0].imshow(query_image)
    axs[0, 0].set_title(f'Query Image: {query_path.split("/")[-1]}')
    axs[0, 0].axis('off')

    for i, path in enumerate(cite_paths):
        similar_image = cv2.imread(path)
        similar_image = cv2.cvtColor(similar_image, cv2.COLOR_BGR2RGB)

        axs[(i+1)//2, (i+1)%2].imshow(similar_image)
        axs[(i+1)//2, (i+1)%2].set_title(f'Similar Image {i+1}: {path.split("/")[-1]}')
        axs[(i+1)//2, (i+1)%2].axis('off')

    # 空白のsubplotを削除
    if num_similar % 2 != 0:
        axs[num_rows-1, 1].axis('off')

    plt.tight_layout()
    plt.show()


def get_qyery_and_cite_path(submission_df, query_gid=None, k=4):
    if query_gid is None:
        query_gid = submission_df["gid"].sample(1).to_numpy()[0]

    cites = submission_df.loc[submission_df["gid"] ==query_gid, "cite_gid"].to_numpy()[0].split(" ")[:k]

    query_path = QUERY_IMAGES / f"{query_gid}.jpg"
    cite_paths = [(CITE_IMAGES / f"{cite_gid}.jpg").as_posix() for cite_gid in cites]
    return {"query_path":query_path.as_posix(), "cite_paths":cite_paths}


def plot_sake(submission_df, query_gid=None, k=11):
    path_dict = get_qyery_and_cite_path(submission_df, query_gid=query_gid, k=k)
    display_similar_images(**path_dict)


# plot_sake(submission_df, query_gid=200108186, k=5)
plot_sake(submission_df, query_gid=None, k=3)
